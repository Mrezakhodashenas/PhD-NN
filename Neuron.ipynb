# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrezakhodashenas/PhD-NN/blob/main/Neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install neuron
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 29.2 MB/s eta 0:00:00
# ...

# %%
# !pip install control
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.1/455.1 kB 5.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pde
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pde: filename=pde-1.3.0-py3-none-any.whl size=6856 sha256=54b64749ccb69ff0c738676ce943fa43af69a37b0dd8e785b7ce8854d6119374
#   Stored in directory: /root/.cache/pip/wheels/2c/d3/f7/141c1e5f70532b6665c4c59c847567ab12a521e8cb352a7c97
# Successfully built pde
# ...

# %%
# !pip show pde
# Out:
# Name: pde
# Version: 1.3.0
# Summary: PDE is a simple development environment setup script for python projects.
# Home-page: http://github.com/Nekroze/Python-DevEnv
# Author: Taylor "Nekroze" Embrace
# Author-email: nekroze@eturnilnetwork.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
# from neuron import h, gui
# from neuron.units import mV, ms, um
from matplotlib import cm
import plotly
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy import signal
import scipy.signal as signal
from numpy.fft import fft, fftfreq, rfft, ifft
# import control
from scipy.integrate import odeint
# import pde
from mpl_toolkits.mplot3d import axes3d
import matplotlib.cm as cm
# from control.matlab import *
import math
from matplotlib.widgets import Cursor
from matplotlib.pyplot import semilogx
from matplotlib import pyplot
# from engineering_notation import EngNumber
# import PySpice.Logging.Logging as Logging
# logger = Logging.setup_logging()
# from PySpice.Doc.ExampleTools import find_libraries
# from PySpice.Probe.Plot import plot
# from PySpice.Spice.Library import SpiceLibrary
# from PySpice.Spice.Netlist import Circuit
# from PySpice.Unit import *
plt.close('all')
import time
start = time.time()

# %%
# freq =  fs*np.arange(len(X))/len(X)

t=np.arange(0,1000,0.025)
fs=1000;
n=np.size(t)
fr=(fs/2)*np.linspace(0,1,n//2)
freqs=fftfreq(n)
mask=freqs>0

# %%
CA1Poz0=pd.read_table("0.12_CA1_inhTau12.dat", sep="\s+", header = None)
CA1Poz0=CA1Poz0.iloc[2:40002,1].values;

CA1Poz0e=pd.read_table("0.25gNaCA1_inhTau12.dat", sep="\s+", header = None)
CA1Poz0e=CA1Poz0e.iloc[2:40002,1].values;

CA1Poz0ee=pd.read_table("1gNaCA1_inhTau12.dat", sep="\s+", header = None)
CA1Poz0ee=CA1Poz0ee.iloc[2:40002,1].values;

# # ================================================================== X (ECdend[65].v(1))
# Sensinf=pd.read_table("ECdend[65].v(1).dat", sep="\s+", header = None)
# Sensinf=Sensinf.iloc[2:40002,1].values;
# fSensinf= fft(Sensinf)
# Sensinf_mag=(1/(60*fs))*abs(fSensinf[0:np.size(t)])
# psdSensinf=np.square(np.abs(fft(Sensinf)/fs))
# # ================================================================== X Epilepsy (ECdendE[65].v(1))
# SensinfE=pd.read_table("ECdendE[65].dat", sep="\s+", header = None)
# SensinfE=SensinfE.iloc[2:40002,1].values;
# fSensinfE=fft(SensinfE)
# SensinfE_mag=(1/(60*n))*abs(fSensinfE[0:np.size(t)])
# psdSensinfE=np.square(np.abs(fft(SensinfE)/n))
# # ================================================================== A1
# ECpyrBuz0=pd.read_table("EC.dat", sep="\s+", header = None)
# ECpyrBuz0=ECpyrBuz0.iloc[2:40002,1].values;
# fECpyrBuz0= fft(ECpyrBuz0)
# ECpyrBuz0_mag=(1/(60*n))*abs(fECpyrBuz0[0:np.size(t)])
# psdECpyrBuz0=np.square(np.abs(fft(ECpyrBuz0)/n))
# # ================================================================== A1e
# ECpyrBuz0E=pd.read_table("ECe.dat", sep="\s+", header = None)
# ECpyrBuz0E=ECpyrBuz0E.iloc[2:40002,1].values;
# fECpyrBuz0E= fft(ECpyrBuz0E)
# ECpyrBuz0E_mag=(1/(60*n))*abs(fECpyrBuz0E[0:np.size(t)])
# psdECpyrBuz0E=np.square(np.abs(fft(ECpyrBuz0E)/n))
# # ================================================================== C1
# CA3Am0=pd.read_table("CA3.dat", sep="\s+", header = None)
# CA3Am0=CA3Am0.iloc[2:40002,1].values;
# fCA3Am0= fft(CA3Am0)
# CA3Am0_mag=(1/(60*n))*abs(fCA3Am0[0:np.size(t)])
# psdCA3Am0=np.square(np.abs(fft(CA3Am0)/n))
# # ================================================================== C1e
# CA3Am0E=pd.read_table("CA3e.dat", sep="\s+", header = None)
# CA3Am0E=CA3Am0E.iloc[2:40002,1].values;
# fCA3Am0E= fft(CA3Am0E)
# CA3Am0E_mag=(1/(60*n))*abs(fCA3Am0E[0:np.size(t)])
# psdCA3Am0E=np.square(np.abs(fft(CA3Am0E)/n))
# # ================================================================== G1
# CA1Poz0=pd.read_table("CA1.dat", sep="\s+", header = None)
# CA1Poz0=CA1Poz0.iloc[2:40002,1].values;
# fCA1Poz0= fft(CA1Poz0)
# CA1Poz0_mag=(1/(60*n))*abs(fCA1Poz0[0:np.size(t)])
# psdCA1Poz0=np.square(np.abs(fft(CA1Poz0)/n))
# # ================================================================== G1e
# CA1Poz0E=pd.read_table("CA1e.dat", sep="\s+", header = None)
# CA1Poz0E=CA1Poz0E.iloc[2:40002,1].values;
# fCA1Poz0E= fft(CA1Poz0E)
# CA1Poz0E_mag=(1/(60*n))*abs(fCA1Poz0E[0:np.size(t)])
# psdCA1Poz0E=np.square(np.abs(fft(CA1Poz0E)/n))
# # ================================================================== H1
# CA1Basket0=pd.read_table("BasketCA1.dat", sep="\s+", header = None)
# CA1Basket0=CA1Basket0.iloc[2:40002,1].values;
# fCA1Basket0= fft(CA1Basket0)
# CA1Basket0_mag=(1/(60*n))*abs(fCA1Basket0[0:np.size(t)])
# psdCA1Basket0=np.square(np.abs(fft(CA1Basket0)/n))
# # ================================================================== H1e
# CA1Basket0E=pd.read_table("BasketCA1e.dat", sep="\s+", header = None)
# CA1Basket0E=CA1Basket0E.iloc[2:40002,1].values;
# fCA1Basket0E= fft(CA1Basket0E)
# CA1Basket0E_mag=(1/(60*n))*abs(fCA1Basket0E[0:np.size(t)])
# psdCA1Basket0E=np.square(np.abs(fft(CA1Basket0E)/n))

# %%
import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 16))

# Set font and figure size
plt.rcParams.update({'font.size': 8})
font = {'weight': 'bold', 'size': 18}

# # # Plot the first subplot
# # # plt.subplot(221)
# plt.plot(t, CA1Poz0, 'green', label='gNa: 0.12mS', linewidth=3)
# plt.ylim(-85, 60)
# plt.xlabel('Time [ms]', fontdict=font)
# plt.ylabel('Membrane potential', fontdict=font)
# # plt.title('Oscillation sample of a biological neuron with Normal vs Mutated gNa\n')
# # # plt.grid(True)
# ax = plt.gca()
# ax.spines['top'].set_linewidth(2)
# ax.spines['right'].set_linewidth(2)
# ax.spines['bottom'].set_linewidth(2)
# ax.spines['left'].set_linewidth(2)
# legend = ax.legend(loc="upper left", frameon=True, fancybox=True, shadow=True, fontsize=15)
# frame = legend.get_frame()
# frame.set_linewidth(2)
# plt.tight_layout()
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# print('min:', min(CA1Poz0), 'max:', max(CA1Poz0))  # Adjust the limits based on your data


# # Plot the second subplot
# # # plt.subplot(222)
# plt.plot(t, CA1Poz0e,'orange', label='gNa: 0.25mS', linewidth=3)
# plt.ylim(-85, 60)
# plt.xlabel('Time [ms]', fontdict=font)
# plt.ylabel('Membrane potential', fontdict=font)
# # plt.grid(True)
# ax = plt.gca()
# ax.spines['top'].set_linewidth(2)
# ax.spines['right'].set_linewidth(2)
# ax.spines['bottom'].set_linewidth(2)
# ax.spines['left'].set_linewidth(2)
# legend = ax.legend(loc="upper left", frameon=True, fancybox=True, shadow=True, fontsize=15)
# frame = legend.get_frame()
# frame.set_linewidth(2)
# plt.tight_layout()
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# print('min:', min(CA1Poz0e), 'max:', max(CA1Poz0e))  # Adjust the limits based on your data

# # Plot the second subplot
# # plt.subplot(223)
plt.plot(t, CA1Poz0ee,'red', label='gNa: 1mS (over-firing)', linewidth=3)
plt.legend(loc="center right", facecolor='white')  # Move the legend to the upper-right corner and change the legend color to white
plt.ylim(-85, 60)
plt.xlabel('Time [ms]', fontdict=font)
plt.ylabel('Membrane potential', fontdict=font)
# plt.grid(True)
ax = plt.gca()
ax.spines['top'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
legend = ax.legend(loc="upper left", frameon=True, fancybox=True, shadow=True, fontsize=15)
frame = legend.get_frame()
frame.set_linewidth(2)
# Adjust spacing between subplots
plt.tight_layout()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
print('min:', min(CA1Poz0ee), 'max:', max(CA1Poz0ee))


# Save the figure in high-quality format
# plt.savefig('OutputfromNeuron.pdf', dpi=300)
# plt.savefig('Neuron_0.12.pdf', dpi=300)
# plt.savefig('Neuron_0.25.pdf', dpi=300)
# plt.savefig('Neuron_1.pdf', dpi=300)

# Display the figure
plt.show()
# Out:
# min: -79.8259 max: 48.7876

# %% [markdown]
# ## one by one

# %%
import matplotlib.pyplot as plt

# Set font and figure size
# plt.rcParams.update({'font.size': 8})
# plt.figure(figsize=(10, 10))

# # Plot the first subplot
# # plt.subplot(311)
# plt.plot(t, CA1Poz0, '#023e8a') # , label='with normal Na conductivity')
# # plt.legend(loc="upper right", fontsize=10)
# plt.ylim(-85, 40)
# plt.xlabel('Time [ms]', fontsize=18)
# plt.ylabel('Membrane potential', fontsize=18)
# # plt.title('Oscillation sample of a biological neuron with Normal vs Mutated gNa\n')
# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)
# # plt.gcf().set_size_inches(6, 4)  # Adjust width and height as needed
# # plt.grid(True)

# # # Plot the second subplot
# # plt.subplot(312)
# plt.plot(t, CA1Poz0e, '#023e8a') # 'black', label='with mutation in Na conductivity')
# # plt.legend(loc="center right")
# plt.ylim(-85, 40)
# plt.xlabel('Time [ms]', fontsize=18)
# plt.ylabel('Membrane potential', fontsize=18)
# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)
# # plt.grid(True)


# Plot the second subplot
# plt.subplot(313)
plt.plot(t, CA1Poz0ee, '#fb8500') # 'black', label='with higher mutation in Na conductivity')
# plt.legend(loc="center right", facecolor='white')  # Move the legend to the upper-right corner and change the legend color to white
plt.ylim(-85, 40)
plt.xlabel('Time [ms]', fontsize=18)
plt.ylabel('Membrane potential', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.grid(True)

plt.tight_layout()
# plt.savefig('NeuronalOutput.png', dpi=300)
plt.show()

# %%
# ##############################======================================= Sensory Information Block
# libraries_path = find_libraries()
# spice_library = SpiceLibrary(libraries_path)

# circuit = Circuit('VCO with BJTn')
# circuit.model('2N3904', 'npn', IS=1E-14, VAF=100, Bf=300, IKF=0.4, XTB=1.5, BR=4,
#               CJC=4E-12, CJE=8E-12, RB=20, RC=0.1, RE=0.1, TR=250E-9,
#               TF=350E-12, ITF=1, VTF=2, XTF=3, VCEO=40)
# R=15
# pulse_width=0.002
# period=0.050
# delay=0.005
# rise=0.0001
# fall=0.010

# circuit.PulseVoltageSource(2, 'cn', circuit.gnd,initial_value=0    , pulsed_value=0.1,
#                             pulse_width=pulse_width, period=period, delay_time=delay, rise_time=rise, fall_time=fall)
# # making another input
# pulse_widthe=0.010
# periode=0.10
# delaye=0.005
# risee=0.0001
# falle=0.010
# circuit.PulseVoltageSource(1, 'c', circuit.gnd,initial_value=0    , pulsed_value=0.1,
#                             pulse_width=pulse_widthe, period=periode, delay_time=delaye, rise_time=risee, fall_time=falle)
# # R=1
# # pulse_width=0.1
# # period=0.20
# # delay=0.005
# # rise=1
# # fall=0.0001
# # circuit.PulseVoltageSource(2, 'cn', circuit.gnd,initial_value=0, pulsed_value=10,
# #                             pulse_width=pulse_width, period=period, delay_time=delay, rise_time=rise, fall_time=fall)
# circuit.BJT(3, 'out2n', 'b2n', circuit.gnd, model='2N3904')
# circuit.BJT(4, 'outn', 'b1n', circuit.gnd, model='2N3904')
# circuit.C(3,'out2n','b1n', 100@u_nF)
# circuit.C(4,'b2n','outn', 100@u_nF)
# circuit.R(5, 'b1n', 'cn', R@u_kΩ)
# circuit.R(6, 'cn', 'b2n', R@u_kΩ)
# circuit.R(7, 'outn', 'ccn', 1@u_kΩ)
# circuit.R(8, 'out2n', 'ccn', 1@u_kΩ)
# circuit.V('Vccn', 'ccn', circuit.gnd, 6@u_V)

# steptime = 1@u_us
# switchingtime = 50@u_ms
# finaltime = 1000@u_ms
# simulator = circuit.simulator(temperature=25, nominal_temperature=25)
# analysis = simulator.transient(step_time=steptime, end_time=finaltime)
# time=np.array(analysis.time)



# #  -----------------------------------------------------Generate Freq Axis
# # ts=np.arange(0,np.size(time),10)
# # ns=np.size(ts)
# frs=(fs/2)*np.linspace(0,1,n)

# fout= np.fft.rfft(analysis['cn'])
# X1=(1/(60*n))*abs(fout[0:np.size(fr)])
# freqss=fftfreq(n)
# masks=freqss>0

# foute= np.fft.rfft(analysis['c'])
# X2=(1/(60*n))*abs(foute[0:np.size(fr)])
# # ====================================================================================== Blocks
# Xdend=Sensinf_mag
# Y=CA1Poz0_mag
# A=ECpyrBuz0_mag/(Xdend+Y)
# C=CA3Am0_mag/ECpyrBuz0_mag;
# F=CA1Basket0_mag/Y;
# D=Y/(CA3Am0_mag-CA1Basket0_mag);
# K=D/(1+(D*F));

# TF=(A*C*K)/(1-(A*C*K))
# # Y1=X1*(TF)
# # ============================================================== Epil Blocks
# Xdende=SensinfE_mag
# Ye=CA1Poz0E_mag
# Ae=ECpyrBuz0E_mag/(Xdende+Ye)
# Ce=CA3Am0E_mag/ECpyrBuz0E_mag;
# Fe=CA1Basket0E_mag/Ye;
# De=Ye/(CA3Am0E_mag-CA1Basket0E_mag);
# Ke=De/(1+(De*Fe));
# # Y2=(X2*((Ae*Ce*Ke)/(1-(Ae*Ce*Ke))))



# # --------------------------------------------------------- plotting Simulated Sens Infor
# # plt.figure()
# # plt.subplot(321)
# # plot(analysis['cn'], label='Period=%.1fms,  pulse_width=%.fms' % (period*1000,pulse_width*1000))
# # plt.legend()
# # plt.xlabel('Time [s]')
# # plt.title('X1 Input from Circuit + FFT')
# # plt.ylabel('Amplitude')
# # plt.show()

# # plt.subplot(323)
# # plt.xlim([0, 600])
# # # plt.ylim([0, 20])
# # plt.plot(X1,label='FFT of the simulated SensInf,  period=%.1fms,  pulse_width=%.fms' % (period*1000,pulse_width*1000))
# # # plt.plot(outf_mag,label='FFT of the VCO Output, R=%.1fk, Sine F=%.fHz, Ampl=%.f, delay=%.fms, Df=%.f' % (R,freq,amp, Td*1000, Df))
# # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.legend()
# # plt.grid()
# # plt.show()


# # plt.subplot(322)
# # plot(analysis['c'],'r', label='Period=%.1fms,  pulse_width=%.fms' % (periode*1000,pulse_widthe*1000))
# # plt.legend()
# # plt.title('X2 Input from Circuit + FFT')
# # plt.xlabel('Time [s]')
# # plt.ylabel('Amplitude')


# # plt.subplot(324)
# # plt.xlim([0, 600])
# # # plt.ylim([0, 20])
# # plt.plot(X2,'r',label='FFT of the simulated SensInf,  period=%.1fms,  pulse_width=%.fms' % (periode*1000,pulse_widthe*1000))
# # # plt.plot(outf_mag,label='FFT of the VCO Output, R=%.1fk, Sine F=%.fHz, Ampl=%.f, delay=%.fms, Df=%.f' % (R,freq,amp, Td*1000, Df))
# # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.legend()
# # plt.grid()
# # plt.show()
# # # ======================================================================================= inverse FFT

# # plt.subplot(325)
# # # plt.plot(Y1,'b',label='X(sim)1*(A.C.K/(1-A.C.K))')
# # plt.plot(t, ifft(X1), 'b',label='inverse (X1)')
# # # plt.xlim([0, 1000])
# # # plt.ylim([-.0010, 0.2])
# # # plt.xlabel('Freq [Hz]')
# # plt.xlabel('Time [s]')
# # plt.ylabel('Amplitude')
# # plt.legend()
# # plt.tight_layout()
# # plt.show()
# # plt.subplot(326)
# # plt.plot(t, ifft(X2), 'r',label='inverse (X2)')  # ifft inverses the fft
# # plt.xlabel('Time [s]')
# # plt.ylabel('Amplitude')
# # plt.tight_layout()   # automatically adjusts subplot params so that the subplot(s) fits in to the figure area.
# # plt.show()
# # # --------------------------------------------------------- plotting ECdend[65] input
# # plt.figure()
# # plt.subplot(311)
# # plt.plot(t, Sensinf, label='dend[65].v(1)')
# # # plt.plot(t, SensinfE, label='Epil dend[65].v(1)')
# # plt.title("Voltage of dend[65] + FFT")
# # plt.legend()
# # plt.subplot(312)
# # plt.plot(Sensinf_mag,label='FFT of EC.dend[65].v(1)= Sensory Information')
# # # plt.plot(SensinfE_mag,label='FFT of Epil EC.dend[65].v(1)= Sensory Information')
# # # plt.plot(outf_mag,label='FFT of the VCO Output, R=%.1fk, Sine F=%.fHz, Ampl=%.f, delay=%.fms, Df=%.f' % (R,freq,amp, Td*1000, Df))
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.20])
# # plt.title("Sens inf FFT (X)")
# # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.legend()
# # plt.grid()
# # plt.tight_layout()

# # # # ======================================================================================= inverse FFT
# # plt.subplot(313)
# # plt.plot(t, ifft(Sensinf_mag), 'b',label='inverse of (Sensinf_mag)= Sensinf(t)')
# # plt.xlabel('Time [s]')
# # plt.ylabel('Amplitude')
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# ##############################=================================================== CA1 Time domain
# plt.figure()
# plt.subplot(211)
# plt.plot(t,CA1Poz0, 'black',label='Normal CA1 Output')
# plt.legend()
# plt.xlabel('Time [ms]');
# plt.ylabel('CA1 Output potential');
# plt.title('CA1 Output with healthy and weak Interneuron')
# plt.grid()
# plt.show()

# plt.subplot(212)
# plt.plot(t,CA1Poz0E,label='CA1 with Weak interneurons')
# plt.legend()
# plt.xlabel('Time [ms]');
# plt.ylabel('Epil CA1 Output');
# plt.grid()
# plt.show()
# # ##############################=================================================== BasketCa1 Time domain
# # plt.figure()
# # plt.subplot(211)
# # plt.plot(t,CA1Basket0, 'black',label='Interneuron (normal)')
# # plt.legend()
# # plt.xlabel('Time [ms]');
# # plt.ylabel('BasketCA1 Output potential');
# # plt.title('BasketCA1 Output w ith healthy and weak Interneuron')
# # plt.ylim([-80, 35])
# # plt.grid()
# # plt.show()

# # plt.subplot(212)
# # plt.plot(t,CA1Basket0E,label='Epil Interneuron (weak)')
# # plt.legend()
# # plt.xlabel('Time [ms]');
# # plt.ylabel('Epil BasketCA1 Output');
# # plt.ylim([-80, 35])
# # plt.grid()
# # plt.show()




# # # --------------------------------------------------------- plotting each Block Transfer Function
# # # --------------------------------------------------------- EC
# plt.figure()
# plt.subplot(211)
# # plt.plot((((A*C*K)/(1-(A*C*K)))),'b',label='(A.C.K/(1-A.C.K))')
# plt.plot(A,'b',label='TF of EC block (A)')
# plt.xlim([0, 1000])
# plt.title("'A & Ae' Transfer Function (EC)")
# plt.legend()
# plt.tight_layout()
# plt.show()

# plt.subplot(212)
# plt.plot(Ae,'r',label='Epil EC block TF (Ae)')
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([-.0010, 0.1])
# plt.ylabel('Ampl [db]')
# plt.legend()
# plt.tight_layout()
# plt.subplots_adjust(left= 0.086, bottom= 0.156, right= 0.966, top= 0.937, wspace=200, hspace= 0.200 )
# plt.show()

# # --------------------------------------------------------- CA3

# plt.figure()
# plt.subplot(211)
# plt.plot(C,'b',label='CA3 block TF (C)')
# plt.title("'C & Ce' Transfer Function (CA3)")
# plt.legend()
# plt.xlim([0, 1000])
# plt.tight_layout()
# plt.show()
# # plt.xlim([0, 600])
# # plt.ylim([-.0010, 0.1])

# plt.subplot(212)
# plt.plot((Ce),'r',label='Epil CA3 block TF (Ce)')
# plt.legend()
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# plt.tight_layout()
# plt.subplots_adjust(left= 0.086, bottom= 0.156, right= 0.966, top= 0.937, wspace=200, hspace= 0.200 )
# plt.show()


# # --------------------------------------------------------- CA1
# plt.figure()
# plt.subplot(211)
# plt.plot(D,'b',label='CA1 block TF (D)')
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([-.0010, 0.1])
# plt.title("'D & De' Transfer Function (CA1)")
# plt.legend()
# plt.tight_layout()
# plt.show()


# plt.subplot(212)
# plt.plot(De,'r',label='Epil CA1 block TF (De)')
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([-.0010, 0.1])
# plt.legend()
# plt.tight_layout()
# plt.show()

# # --------------------------------------------------------- BasketCA1
# plt.figure()
# plt.subplot(211)
# plt.plot((F),'b',label='BasketCA1 block TF (F)')
# plt.legend()
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# plt.tight_layout()
# plt.title("'F' Transfer Function (BasketCA1)")
# plt.show()

# plt.subplot(212)
# plt.plot((Fe),'r',label='Epil BasketCA1 block TF (Fe)')
# plt.legend()
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# plt.tight_layout()
# plt.show()
# # --------------------------------------------------------==============================- Total TF
# plt.figure()
# plt.subplot(211)
# plt.plot(((A*C*K)/(1-(A*C*K))),'b',label='(A.C.K/(1-A.C.K)) TF')
# plt.legend()
# plt.xlim([0, 1000])
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# plt.tight_layout()
# plt.title("Total Transfer Function")
# plt.show()

# plt.subplot(212)
# plt.plot((Ae*Ce*Ke)/(1-(Ae*Ce*Ke)),'r',label='Epil Total TF')
# plt.xlim([0, 1000])
# plt.legend()
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# plt.tight_layout()
# plt.show()
# # =====================================================================   Test for outputs
# plt.figure()
# plt.subplot(221)
# plt.plot((Xdend*((A*C*K)/(1-(A*C*K)))),'b',label='X*(A.C.K/(1-A.C.K))')
# plt.xlim([0, 600])
# plt.ylim([-.0010, 0.1])
# plt.title("Convolution of Normal Cells Vs CA1 output")
# # plt.xlabel('Freq [Hz]')
# plt.ylabel('Ampl [db]')
# plt.legend()
# plt.tight_layout()
# plt.show()
# plt.subplot(223)
# plt.plot((Y),'b',label='FFT for Normal [CA1]= Y')
# plt.legend()
# plt.xlim([0, 600])
# plt.ylim([0, 0.1])
# plt.xlabel('Freq [Hz]')
# plt.ylabel('Ampl [db]')
# plt.tight_layout()
# # plt.subplots_adjust(left= 0.086, bottom= 0.156, right= 0.966, top= 0.937, wspace=200, hspace= 0.200 )

# plt.subplot(222)
# plt.plot((Xdende*((Ae*Ce*Ke)/(1-(Ae*Ce*Ke)))),'r',label='Epil X*(A.C.K/(1-A.C.K))')
# plt.xlim([0, 600])
# plt.ylim([-.0010, 0.1])
# plt.title("Convolution of Epil Cells Vs CA1 output")
# # plt.xlabel('Freq [Hz]')
# plt.ylabel('Ampl [db]')
# plt.legend()
# plt.tight_layout()
# plt.show()
# plt.subplot(224)
# plt.plot((Ye),'r',label='FFT for Epil [CA1]= Ye')
# plt.legend()
# plt.xlim([0, 600])
# plt.ylim([0, 0.1])
# plt.xlabel('Freq [Hz]')
# plt.ylabel('Ampl [db]')
# plt.tight_layout()
# # plt.subplots_adjust(left= 0.086, bottom= 0.156, right= 0.966, top= 0.937, wspace=200, hspace= 0.200 )

# # ====================================================-----------------========= Simulated Inputs from Circuit
# # plt.figure()
# # plt.subplot(221)
# # plt.plot(Y1,'b',label='X(sim)1*(A.C.K/(1-A.C.K))')
# # plt.xlim([0, 1000])
# # plt.ylim([-.0010, 0.2])
# # # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.title("Circuit Simulated Input Vs CA1 outputs (Y1 & Y)")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# # plt.subplot(223)
# # plt.plot((Y),'b',label='FFT for Normal [CA1]= Y')
# # plt.legend()
# # plt.xlim([0, 1000])
# # plt.ylim([-.0010, 0.2])
# # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.tight_layout()
# # # plt.subplots_adjust(left= 0.086, bottom= 0.156, right= 0.966, top= 0.937, wspace=200, hspace= 0.200 )

# # plt.subplot(222)
# # # plt.plot((Xe*((Ae*Ce*Ke)/(1-(Ae*Ce*Ke)))),'r',label='Epil X(sim)*(A.C.K/(1-A.C.K))')
# # plt.plot(Y2,'r',label='X(sim)2*(Ae.Ce.Ke/(1-Ae.Ce.Ke))')
# # plt.xlim([0, 1000])
# # plt.ylim([-.0010, 0.2])
# # # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.title("Circuit Simulated Input Vs CA1 outputs (Y2 & Ye)")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# # plt.subplot(224)
# # plt.plot((Ye),'r',label='FFT for Epil [CA1]= Ye')
# # plt.legend()
# # plt.xlim([0, 1000])
# # plt.ylim([-.0010, 0.2])
# # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.tight_layout()





# # ==================================================================== Differences between Y and cell vonvolution
# # plt.figure(4)
# # plt.plot(Y-(X*((A*C*K)/(1-(A*C*K)))),'r',label='Y - (A.C.K/(1+A.C.K))X')

# # ==================================================================== Epileptic mode
# # plt.figure(4)
# # plt.subplot(211)
# # Ge=ECpyrBuz0E_mag*CA3Am0E_mag;
# # He=CA1Basket0E_mag;

# # # plt.plot((ECpyrBuz0_mag*Gran0_mag*100),label='Entorhinal*Granuale')
# # # plt.plot((ECpyrBuz0_mag*Gran0_mag*CA3Am1_mag*1000),'green',label='Entorhinal*Granuale*CA3')
# # # plt.plot((ECpyrBuz1_mag*Gran0_mag*CA3Am0_mag*1000),'green',label='2nd Entorhinal*Granuale*CA3')
# # # plt.plot((ECpyrBuz1_mag*Gran0_mag*CA3Am1_mag*1000),'green',label='3rd Entorhinal*Granuale*CA3')
# # plt.plot(15*Ge/(1+(Ge*He)),'red',label='Ge/1+Ge.He')
# # # plt.plot((G),'green',label='Entorhinal*CA3')
# # # plt.plot((ECpyrBuz1_mag*Gran0_mag*CA3Am1_mag*100),label='FFT for Normal [A*B*C]')
# # # plt.plot((CA1Poz0_mag),label='FFT for Normal [D]')
# # # plt.plot(40*(Gran0_mag*CA3Am1_mag),label='FFT for Normal [A*B] with "1s" Stimulation')
# # # plt.plot(Subic1E_mag,'--', label='Less gNa in All interneurons')
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# # plt.title("Convolution of Cells")
# # # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.legend()
# # plt.tight_layout()
# # plt.show()
# # plt.subplot(212)
# # plt.plot((CA1Poz0E_mag),label='FFT for Epileptic Final Output (CA1e)')
# # plt.plot((CA1Basket0E_mag),label='FFT for Epileptic Basket cell (BasketCA1e)')
# # plt.legend()
# # plt.xlim([0, 600])
# # plt.ylim([0, 0.1])
# # plt.xlabel('Freq [Hz]')
# # plt.ylabel('Ampl [db]')
# # plt.tight_layout()
# # plt.subplots_adjust(left= 0.086, bottom= 0.106, right= 0.966, top= 0.937, wspace=200, hspace= 0.100 )

# # =============================================================== Printing Cross correlation of CA1poz0 and A*B*C blocks
# # maxlags=50

# # plt.xcorr((X*((A*C*K)/(1-(A*C*K)))), Y, usevlines=False, color='black', maxlags=maxlags, normed=True, lw=2,label='Cross-Correlation Coeff of  D & A*B*C with 0-lag' )
# # coords=plt.gca().lines[0].get_xydata() # Get coords for most recently plotted lineplt.grid()
# # plt.legend()
# # print("Cross-correlation coefficient between  D & A*B*C with 0-lag is: (%% %.3f)" %(coords[maxlags,1]*100))
# # # =============================================================== Cross correlation of CA1poz0 and A*B*C blocks
# # # plt.subplot(212)
# # plt.figure(4)
# # plt.xcorr((X*((A*C*K)/(1-(A*C*K)))), Y, usevlines=True, color='blue', maxlags=maxlags, normed=True, lw=2,label='Correlation Coefficient: (%% %.3f)' % (coords[maxlags,1]*100))
# # plt.grid()
# # plt.legend()
# # plt.ylabel('Correlation Coeff')
# # plt.title('Cross-correlation between  D & A*B*C with 0-lag')

# # ========================================== PSD for Normal block with "1s" Stimulation
# # plt.figure()
# # plt.plot(psdCA1Poz0[mask], label='PSD for Normal [CA1] with "1s" Stimulation')
# # plt.plot(psdCA1Poz0E[mask],'--', label='Less gNa in All interneurons')
# # # plt.xlim([0, 405])
# # # plt.ylim([-3, 85])
# # plt.legend()
# # plt.tight_layout()
# # plt.grid()
# # plt.show()

# # psdSensinf
# # psdSensinfE
# # psdECpyrBuz0
# # psdECpyrBuz0E
# # psdCA3Am0
# # psdCA3Am0E
# # psdCA1Poz0
# # psdCA1Poz0E
# # psdCA1Basket0
# # psdCA1Basket0E






# # ==================================================================================== Just the Block FFT not CA1

# %%
# # h.load_file('JustThree.ses')
# # h.load_file('May3aftCreateCA1Epil.hoc')
# # h.load_file('stdrun.hoc')
# # -------------------------------------------------------------------
# x=[0, 0.1, 0.2, 0.5, 0.7, 1, 1.1, 1.2, 1.3, 1.4, 1.5, 1.51, 1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59, 1.592, 1.6, 1.7, 1.8, 1.9, 2, 3, 4, 5, 6, 7, 8, 9, 10]
# vdend=[-64.97, -63.97, -62.98, -59.94, -57.87, -54.52, -53.32, -52.03, -50.60, -48.92, -46.61, -46.28, -45.93, -45.55, -45.10, -44.59, -43.95, -43.08, -41.68, -37.51, -33.42, 3.46, 11.22, 14.02, 15.69, 17.11,
#        26.10, 32.90, 38.81, 44.97, 50.17, 56.06, 60.97, 66.23]
# vsoma=[-64.97, -64.78, -64.6, -64.03, -63.62, -62.88, -62.60, -62.29, -61.91, -61.45, -60.74, -60.63, -60.50, -60.37, -60.22, -60.04, -59.83, -59.52, -59.05, -57.49, -53.2, 25.96, 29.4, 30.26, 30.94, 30.10,
#        31.93, 31.30, 31.06, 32.64, 32.02, 33.10, 32.52, 31.32 ]
# # -------------------------------------------------------------------
# # h.topology()  # shows the topology

# # axon = h.Section()
# # axon.nseg = 75
# # axon.diam = 100
# # axon.L = 20000
# # axon.insert('hh')

# # #=================================== connect the cells

# # PostSyn = h.ExpSyn(PostCell.dend[0](0.5))   # ExpSyn: g changes by a weight
# # PreSyn = PreCell.axon(1)._ref_v    # g decays exponentially with time constant

# # pc = h.ParallelContext()    # to connect to cells in different machines
# # nc = h.NetCon(PreSyn, PostSyn)
# # nc.delay = 1.0
# # nc.weight = 0.001
# # =========================================================
# # h.hh.insert(h.allsec())

# # soma = h.Section(name='soma')
# # soma.L = soma.diam = 10 *um
# # soma.insert(h.hh)

# # ic = h.IClamp(soma(0.5))
# # ic.delay = 1*ms
# # ic.dur = 1*ms
# # ic.amp = 1

# # t = h.Vector().record(h._ref_t)
# # v = h.Vector().record(soma(0.5)._ref_v)

# # h.finitialize(-65*mV)
# # h.continuerun(20*ms)

# # ========================================== plot
# # ps = h.PlotShape(False)
# # ps.variable('v')
# # ps.plot(plotly, cmap=cm.cool).show()
# # =======================================
# plt.plot(x,vdend, '--', color='black',label='EC Dendrite')
# plt.plot(x,vsoma, '--', color='red',label='EC Soma')

# plt.title('Action Potential Probability Distribution')
# # plt.ylim(-90, 50)
# plt.xlabel('Current Amplitute (nA)')
# plt.ylabel('Action Potential prob')
# plt.legend()
# plt.show()

# # begintemplate SenInf_NetStim
# # public pp, connect2target, x, y, z, position, is_art
# # objref pp
# # proc init() {
# #   pp = new NetStim()
# #     pp.interval = 50
# #     pp.number = 20
# #     pp.start = 5
# # }
# # func is_art() { return 1 }
# # obfunc connect2target() { localobj nc
# #   nc = new NetCon(pp, $o1)
# #   if (numarg() == 2) { $o2 = nc }
# #   return nc
# # }
# # proc position(){x=$1  y=$2  z=$3}
# # endtemplate SenInf_NetStim
