# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrezakhodashenas/PhD-NN/blob/Mrezakhodashenas-Noise_Investigation/GaussianNoise_input_stddev_mean_Investigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reset -f

# %%
# !pip install wandb --upgrade
# Out:
# Collecting wandb
#   Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.40.4-py2.py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.9/257.9 kB 17.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.42 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.40.4 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.3

# %%
# !pip install wandb onnx -Uq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 54.1 MB/s eta 0:00:00

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
# !pip install pytorch-lightning
# Out:
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.2.0.post0-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.9/800.9 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.3.1-py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.4/840.4 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.9.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.10.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch-lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.10.1 pytorch-lightning-2.2.0.post0 torchmetrics-1.3.1

# %%
# !pip install snntorch
# Out:
# Collecting snntorch
#   Downloading snntorch-0.7.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from snntorch) (2.1.0+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from snntorch) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from snntorch) (3.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from snntorch) (1.25.2)
# Collecting nir (from snntorch)
#   Downloading nir-1.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 9.9 MB/s eta 0:00:00
# Collecting nirtorch (from snntorch)
#   Downloading nirtorch-1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (2.8.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from nir->snntorch) (3.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->snntorch) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->snntorch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->snntorch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.1.0->snntorch) (1.3.0)
# Installing collected packages: nir, nirtorch, snntorch
# Successfully installed nir-1.0.1 nirtorch-1.0 snntorch-0.7.0

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-1.4.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.25.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.2.2)
# Collecting colorama>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.2.0)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-1.4.3 colorama-0.4.6

# %% [markdown]
# ## set seeds for PyTorch and Numpy to ensure reproducibility:

# %%
import torch
import random
import numpy as np

# Set seeds for Python, Numpy, and Torch for reproducibility
# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)


# seed = 42
# random.seed(seed)
# np.random.seed(seed)
# torch.manual_seed(seed)
# torch.cuda.manual_seed_all(seed)

# Additional steps if you're using GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# imports
import pickle
import matplotlib.animation as animation
from scipy.integrate import simps
import torch
torch.cuda.empty_cache()
import os, sys, time, datetime, json, random
import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision import utils as utls
from snntorch import utils
from snntorch import surrogate
import numpy as np
import math
from sklearn.metrics import auc
from torchsummary import summary
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import torch.nn as nn
from scipy.stats import entropy
from scipy.special import kl_div
from torch.autograd import Variable
from sklearn.metrics import accuracy_score
# from skopt import gp_minimize
from bayes_opt import BayesianOptimization
import wandb
from tqdm.auto import tqdm
import matplotlib.ticker as mtick



# import spikeflow as snn

# %%
# fe7dfc869c7793392e4f225d9d64f615e2fd70ec
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: ERROR API key must be 40 characters long, yours was 42
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
wandb.init(project="GaussianNoise_input_stddev_mean_Investigation")      # Set the project where this run will be logged

config = dict(
    mean_num_intervals = 6,         # Adjust the number of intervals as needed
    mean_range = np.linspace(0, 1), # mean_num_intervals),
    stddev_num_intervals = 11,  # Adjust the number of intervals as needed
    std_dev_range = np.linspace(0, 1), # stddev_num_intervals),
    subset_fraction = 0.05,     # the percentage of the data used
    epochs=3,

    batch_size=250,
    learning_rate=0.0001,
    input_size = 32,
    kernels=[32, 64, 128],
    threshold_Real = 0.5,
    threshold_Recon = 0.5,

    alpha=0.9,
    beta_syn=0.0001,
    # beta_syn=0.9,
    beta =0.9,
    num_steps=5,
    latent_dim = 32, #dimension of latent layer (how compressed we want the information)
    thresh=1,    #spiking threshold (lower = more spikes are let through)

    lr=0.0001,
    betas=(0.9, 0.999),
    weight_decay=0.001,

    dataset="MNIST",
    architecture="SAE(L_Syn_Syn_L)")
# Out:
# Finishing last run (ID:6cxtxyw8) before initializing another...
# VBox(children=(Label(value='0.010 MB of 0.010 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">twinkling-envelope-1</strong> at: <a href='https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation/runs/6cxtxyw8' target="_blank">https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation/runs/6cxtxyw8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240216_193412-6cxtxyw8/logs</code>
# Successfully finished last run (ID:6cxtxyw8). Initializing new run:<br/>
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240216_193424-yzyna0s3</code>
# Syncing run <strong><a href='https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation/runs/yzyna0s3' target="_blank">lambent-noodles-2</a></strong> to <a href='https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation' target="_blank">https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation</a>
#  View run at <a href='https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation/runs/yzyna0s3' target="_blank">https://wandb.ai/neuroscience_ai/GaussianNoise_input_stddev_mean_Investigation/runs/yzyna0s3</a>

# %%
# /////////////////////# Building the Autoencoder
#-------------------DataLoaders.  using the MNIST dataset

# dataloader arguments
batch_size = 250
data_path='/data/mnist'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")


# /////////////////////////////////# Define a transform
input_size = 32 # resizing the original MNIST from 28 to 32

transform = transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize((0,), (1,))])

# #------------------------------------------- Load MNIST
# # Training data
train_dataset = datasets.MNIST(root='dataset/', train=True, transform=transform, download=True)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# # Testing data
test_dataset = datasets.MNIST(root='dataset/', train=False, transform=transform, download=True)
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)


from torch.utils.data import Subset, DataLoader

# Defining the fraction of the dataset to use (e.g., 0.1 for 10%)
subset_fraction = 0.05

# Calculate the number of samples to include in the subset
subset_size = int(len(train_dataset) * subset_fraction)
subset_size_test = int(len(test_dataset) * subset_fraction)

# Create a subset of the training dataset
subset_indices = torch.randperm(len(train_dataset))[:subset_size]
train_subset = Subset(train_dataset, subset_indices)
# Create DataLoader for the subset
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)

# Similarly, create a subset of the test dataset if needed
test_subset_indices = torch.randperm(len(test_dataset))[:subset_size]
test_subset = Subset(test_dataset, test_subset_indices)
test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False)

# Now, you can use train_loader_subset and test_loader_subset for training and testing

# %%
# creating directories where we can save the original and reconstructed images for training and testing:
# create training/ and testing/ folders in the chosen path
if not os.path.isdir('figures/training'):
    os.makedirs('figures/training')
if not os.path.isdir('figures/binarytraining'):
    os.makedirs('figures/binarytraining')

if not os.path.isdir('figures/testing'):
    os.makedirs('figures/testing')
if not os.path.isdir('figures/binarytesting'):
    os.makedirs('figures/binarytesting')


if not os.path.isdir('Saved_Trained_Checkpoints/'):
    os.makedirs('Saved_Trained_Checkpoints/')

if not os.path.isdir('Output_Spikes/'):
    os.makedirs('Output_Spikes/')

if not os.path.isdir('Enc_syn_Spikes/'):
    os.makedirs('Enc_syn_Spikes/')


if not os.path.isdir('Intermediate_Lyrs/'):
    os.makedirs('Intermediate_Lyrs/')

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using {torch.cuda.get_device_name()} ({device})")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using CPU

# %%
class SAE(nn.Module):
    def __init__(self):
        super().__init__()


        # Encoder
        self.encoder = nn.Sequential(
                            nn.Conv2d(1, 32, 3,padding = 1,stride=2), # Conv Layer 1
                            nn.BatchNorm2d(32),
                            snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True,threshold=thresh),
                            nn.Conv2d(32, 64, 3,padding = 1,stride=2), # Conv Layer 2
                            nn.BatchNorm2d(64),
                            snn.Synaptic(alpha=alpha, beta=beta_syn, spike_grad=spike_grad, init_hidden=True, threshold=thresh), #SNN TORCH LIF NEURON
                            nn.Conv2d(64, 128, 3,padding = 1,stride=2), # Conv Layer 3
                            nn.BatchNorm2d(128),
                            snn.Synaptic(alpha=alpha, beta=beta_syn, spike_grad=spike_grad, init_hidden=True,threshold=thresh), #SNN TORCH LIF NEURON
                            nn.Flatten(start_dim = 1, end_dim = 3), #Flatten convolutional output
                            nn.Linear(128*4*4, latent_dim), # Fully connected linear layer
                            snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True, output=True,threshold=thresh)
                            )


        self.latent_dim = latent_dim #dimensions of the encoded z-space data
        self.linearNet= nn.Sequential(
                                      nn.Linear(latent_dim,128*4*4),
                                      snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True, output=True,threshold=thresh))

        # Decoder:
        self.decoder = nn.Sequential(
                            nn.Unflatten(1,(128,4,4)), #Unflatten data from 1 dim to tensor of 128 x 4 x 4
                            snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True,threshold=thresh),
                            nn.ConvTranspose2d(128, 64, 3,padding = 1,stride=(2,2),output_padding=1),
                            nn.BatchNorm2d(64),
                            snn.Synaptic(alpha=alpha, beta=beta_syn, spike_grad=spike_grad, init_hidden=True,threshold=thresh),
                            nn.ConvTranspose2d(64, 32, 3,padding = 1,stride=(2,2),output_padding=1),
                            nn.BatchNorm2d(32),
                            snn.Synaptic(alpha=alpha, beta=beta_syn, spike_grad=spike_grad, init_hidden=True,threshold=thresh),
                            nn.ConvTranspose2d(32, 1, 3,padding = 1,stride=(2,2),output_padding=1),
                            snn.Leaky(beta=beta, spike_grad=spike_grad, init_hidden=True,output=True,threshold=20000) #so membrane can be trained
                            )
    def forward(self, x):
        utils.reset(self.encoder) #need to reset the hidden states of LIF
        utils.reset(self.decoder)
        utils.reset(self.linearNet)

    #-----------------------------encode
        spk_mem=[];
        spk_rec=[];
        spk_rec_syn=[];
        encoder_mem=[];
        spk_rec_dec=[];
        spk_mem_dec=[];
        enc5_rec = [];


     #------------------------------ intermediate layers

        # for step in range(num_steps):
        #     enc5 = self.encoder[5](x)             #  enc5 shape: torch.Size([250, 1, 32, 32])
        #     enc5_rec.append(enc5)
        # enc5_rec = torch.stack(enc5_rec, dim=2)            #   enc5_rec size: torch.Size([250, 1, 5, 32, 32])
        # Enc_syn_1 = enc5_rec[:, :, -1]                      # #   torch.Size([250, 1, 32, 32])

     #------------------------------ encode
        for step in range(num_steps):
            spk_x, mem_x = self.encoder(x)              # spk_x size: ([250, 32])  ,   mem_x size: ([250, 32])  , x.shape : torch.Size([250, 1, 32, 32])

           #--------------------- Add noise to the membrane potential
            # mem_x += torch.randn_like(mem_x) * std_dev
            # spk_x += torch.randn_like(spk_x) * std_dev

            # noise_level = 0.1  # Adjust the noise level
            # spike_rate = noise_level * torch.ones_like(spk_x)  # Constant rate for Poisson distribution
            # spk_x += torch.poisson(spike_rate)

           #---------------------
            spk_rec.append(spk_x)
            spk_mem.append(mem_x)

        spk_rec=torch.stack(spk_rec,dim=2) # stack spikes in second tensor dimension # ----------------spk_rec in torch.stack(spk_rec,dim=2):  torch.Size([250, 32, 5])
        spk_mem=torch.stack(spk_mem,dim=2) # stack membranes in second tensor dimension # ----------------spk_mem in torch.stack(spk_mem,dim=2):  torch.Size([250, 32, 5])
        out_en = spk_rec[...,step]

        # print("out_en= spk_rec[...,step]:-----------" , spk_rec[...,step].size()) # spk_rec[...,step]:----------- torch.Size([250, 32])       input of the latent and then decoder

     #------------------------------decode
        spk_mem2=[];
        spk_rec2=[];
        decoded_x=[];
        spk_x_dec=[];
        mem_x_dec=[];
        for step in range(num_steps): #for t in time                           #        from decoder: ([250, 1, 32, 32])
            x_recon, x_mem_recon = self.decode(spk_rec[...,step])
            spk_rec2.append(x_recon)
            spk_mem2.append(x_mem_recon)

        spk_rec2=torch.stack(spk_rec2,dim=4)
        spk_mem2=torch.stack(spk_mem2,dim=4)

        out = spk_mem2[:,:,:,:,-1]

        self.out_en = out_en
        self.out = out

        return out, out_en
        # return out, Enc_syn_1


    #     # Initialize Gaussian noise parameters
    #     self.noise_mean = 0.0
    #     self.noise_std = 0.1  # Adjust the standard deviation as needed


    # def add_noise(self, layer):
    #     if isinstance(layer, snn.Synaptic):
    #         # Add Gaussian noise to synaptic conductance values
    #         with torch.no_grad():
    #             layer.weight.data += torch.randn_like(layer.weight.data) * self.noise_std + self.noise_mean




    def encode(self,x):
      spk_latent_x, mem_latent_x = self.encoder(x)
      return spk_latent_x, mem_latent_x


    def decode(self,x):
        spk_x, mem_x = self.linearNet(x) #convert latent dimension back to total size of features in encoder final layer
        spk_x2, mem_x2 = self.decoder(spk_x)
        return spk_x2, mem_x2

# %%
import numpy as np

def calculate_pixel_accuracy(real_img, x_recon):
    # Flatten the tensors and convert them to NumPy arrays
    real_img_np = real_img.flatten().cpu().numpy()
    x_recon_np = x_recon.flatten().detach().cpu().numpy()

    # Calculate pixel-wise similarity
    pixel_accuracy = 1 - np.mean(np.abs(x_recon_np - real_img_np))

    return pixel_accuracy

# %%
# Training and Testing
# using MSE loss to compare the reconstructed image (x_recon) with the original image (real_img)
from torchvision.utils import save_image

spike_recordings = []
train_ber_rec = []
test_ber_rec = []
threshold_Real = 0.5
threshold_Recon = 0.5


def train(network, trainloader, opti, epoch, std_dev, mean):
    # Tell wandb to watch what the model gets up to: gradients, weights, and more!
    wandb.watch(network, log="all", log_freq=10)

    network=network.train()
    train_loss_hist=torch.zeros((1), dtype=dtype, device=device)
    train_avg_loss_rec=[]
    train_loss_rec = []
    train_accuracy = []  # Define train_accuracy list

    for batch_idx, (real_img, labels) in enumerate(trainloader):
        opti.zero_grad()
        real_img = real_img.to(device)
        labels = labels.to(device)

        # -------------Add Gaussian noise to the input images
        real_img = real_img + torch.randn_like(real_img) * std_dev + mean

        # noise_level = 0.9  # Adjust the noise level
        # real_img = noise_level * torch.ones_like(real_img)  # Constant rate for Poisson distribution
        # real_img += torch.poisson(real_img)

        out, out_en = network(real_img)   # Pass data into network and return reconstructed image and spk_rec
        x_recon, out = network(real_img)  # Pass data into network and return reconstructed image and spk_rec.  #  x_recon size torch.Size([250, 1, 32, 32]) ,  # out size torch.Size([250, 32])

        # ---------------------------------

        #Calculate loss
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
          loss_val += F.mse_loss(x_recon, real_img)                  #.view(1, -1)
        train_loss_hist += (loss_val.item())/num_steps
        avg_loss=train_loss_hist.mean()

        # # ---------------------------- Calculate Bit Error Rate (BER)
        real_img_binary = (real_img > threshold_Real).float()
        x_recon_binary = (x_recon > threshold_Recon).float()
        bit_errors = torch.sum(torch.abs(real_img_binary - x_recon_binary))
        total_pixels = real_img_binary.numel()  # Total number of pixels in the images
        bit_error_rate = bit_errors.item() / total_pixels
        train_ber_rec.append(bit_error_rate)  # Append BER to the list

        # # --------------------------------- Calculate Accuracy------------
        # # # accuracy = accuracy_score(real_img.flatten().cpu().numpy(), x_recon.flatten().detach().cpu().numpy())
        train_accuracy_pix = calculate_pixel_accuracy(real_img, x_recon)
        train_accuracy.append(train_accuracy_pix.item())

         # # -----------------------------------------------------------------
        loss_val.backward()
        opti.step()
        train_loss_rec.append(loss_val.item())
# ------------------------------------------------------------------
        # Save binary images
        Error_bin = (torch.abs(x_recon_binary - real_img_binary))

        if batch_idx == len(trainloader)-1:
          if epoch in [0, 25, 49]:
            utls.save_image(real_img_binary, f'figures/binarytraining/ep{epoch}_inputs_binary.png')
            utls.save_image(x_recon_binary, f'figures/binarytraining/ep{epoch}_recon_binary.png')
            utls.save_image(Error_bin, f'figures/binarytraining/ep{epoch}_Error_bin.png')

        # Logging for wandb
        if (batch_idx + 1) % 10 == 0:
          wandb.log({"Epoch": epoch, "Train_Batch": batch_idx, "Train_Loss": loss_val.item(), "Train_BER": bit_error_rate, "Train_Acc": train_accuracy_pix* 100})



        print(f'Std_dev:{std_dev}--Mean:{mean}---[{epoch}/{max_epoch}][{batch_idx}/{len(trainloader)}]  Train_Loss: {loss_val.item():.5f}, ' f'Train_BER: {bit_error_rate:.5f}, Train_Acc: {train_accuracy_pix*100:.4f}%')


        #Save reconstructed images every at the end of the epoch
        if batch_idx == len(trainloader)-1:
          if epoch in [0, 10, 25, 49]:
            utls.save_image((real_img+1)/2, f'figures/training/epoch{epoch}_finalbatch_inputs.png')
            utls.save_image((x_recon+1)/2, f'figures/training/epoch{epoch}_finalbatch_recon.png')
            train_auc = auc(np.arange(len(train_loss_rec)), train_loss_rec)


    # Compute average accuracy for the entire epoch
    epoch_accuracy = sum(train_accuracy) / len(train_accuracy)
    epoch_loss = sum(train_loss_rec) / len(train_loss_rec)
    print(f'----------------Epoch{epoch}/{max_epoch} Train set ---------------')
    print(f'Std_dev:{std_dev}-- Mean:{mean}-- Epoch [{epoch}/{max_epoch}] Train_Avg_loss(epoch): {epoch_loss:.5f}, Train_AvgAcc(epoch): {epoch_accuracy*100:.4f}%')
    print('-------------------------------------')
    wandb.log({"Epoch": epoch, "Trani_AvgLoss(Epoch)": epoch_loss, "Train_AvgAcc(Epoch)": epoch_accuracy * 100})

    return loss_val, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en      # train_accuracy, epoch_accuracy, noisy_out_en -----------------added


# For Testing, not doing backpropagate, therefore no gradients are required and we use torch.no_grad():
#Testing Loop
def test(network, testloader, opti, epoch, std_dev, mean):
    network=network.eval()
    test_loss_hist=[]
    test_avg_loss_rec=[]
    test_avg_loss_hist = []
    test_accuracy = []  # Define test_accuracy list

    spk_rec_test = []
    with torch.no_grad(): #no gradient this time
        for batch_idx, (real_img, labels) in enumerate(testloader):
            real_img = real_img.to(device)#
            labels = labels.to(device)
            out, out_en = network(real_img)  # Pass data into network and return reconstructed image and spk_rec
            x_recon , out = network(real_img)  # Pass data into network and return reconstructed image and spk_rec
            #------------------------------------------------------average Loss:
            loss_val = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
              loss_val += F.mse_loss(x_recon, real_img)
            avg_loss=loss_val/num_steps
            test_loss_hist.append(loss_val.item())
          # --------------------------------------------------------BER---------
            real_img_binary = (real_img > threshold_Real).float()
            x_recon_binary = (x_recon > threshold_Recon).float()
            bit_errors = torch.sum(torch.abs(real_img_binary - x_recon_binary))
            total_pixels = real_img_binary.numel()  # Total number of pixels in the images
            bit_error_rate = bit_errors.item() / total_pixels
            test_ber_rec.append(bit_error_rate)  # Append BER to the list

            # #----------------------------------------------------- Calculate accuracy
            # # # accuracy = accuracy_score(real_img.flatten().cpu().numpy(), x_recon.flatten().detach().cpu().numpy())
            test_accuracy_pix = calculate_pixel_accuracy(real_img, x_recon)
            test_accuracy.append(test_accuracy_pix.item())  # Record accuracy

            # ----------------------------------------------------------------
            # Save binary images
            Error_bin = (torch.abs(x_recon_binary - real_img_binary))

            if batch_idx == len(testloader)-1:
              if epoch in [0, 25, 49]:
                save_image(real_img_binary, f'figures/binarytesting/ep{epoch}_inputs_binary.png')
                save_image(x_recon_binary, f'figures/binarytesting/ep{epoch}_recon_binary.png')
                save_image(Error_bin, f'figures/binarytesting/ep{epoch}_Error_bin.png')
            # -------------------------------------------------------------------------------------------------

            print(f'Std_dev:{std_dev}--- Test[{epoch}/{max_epoch}][{batch_idx}/{len(testloader)}]  Loss(test): {loss_val.item():.5f}, '  f'BER (test): {bit_error_rate:.5f},  Accuracy(test): {test_accuracy_pix*100:.4f}%')
            test_loss_rec.append(loss_val.item())

            if batch_idx == len(testloader)-1:
              if epoch in [0, 10, 25, 49]:
                utls.save_image((real_img+1)/2, f'figures/testing/epoch{epoch}_finalbatch_inputs.png')
                utls.save_image((real_img+(torch.randn_like(real_img) * std_dev)+1)/2, f'figures/testing/(real_img+noise)_epoch{epoch}_finalbatch_inputs.png')
                utls.save_image((x_recon+1)/2, f'figures/testing/epoch{epoch}_finalbatch_recons.png')
                test_auc = auc(np.arange(len(test_loss_rec)), test_loss_rec)

            # Logging for wandb
            if (batch_idx + 1) % 10 == 0:
              wandb.log({"Test_Epoch": epoch, "Test_Batch": batch_idx, "Test_Loss": loss_val.item(), "Test_BER": bit_error_rate, "Test_Acc": test_accuracy_pix* 100})


    # Compute average accuracy for the entire epoch
    epoch_accuracy_test = sum(test_accuracy) / len(test_accuracy)
    epoch_loss_test = sum(test_loss_hist) / len(test_loss_hist)
    print(f'----------------Epoch {epoch}/{max_epoch} Test set ---------------')
    print(f'Std_dev:{std_dev}--Mean:{mean}---Test_Epoch [{epoch}/{max_epoch}] Average loss_test (epoch): {epoch_loss_test:.5f}, Average Accuracy_test (epoch): {epoch_accuracy_test*100:.4f}%')
    print('-----------------------------------------------------------------------------------------')

    wandb.log({"Epoch": epoch, "Test_AvgLoss(Epoch)": epoch_loss_test, "Test_AvgAcc(Epoch)": epoch_accuracy_test * 100})


    return loss_val, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en     # ------------------------------------- noisy_out_en  , test_accuracy ------------------ADDED
    # return loss_val, test_loss_rec, test_auc, out, out_en
    # return loss_val, test_loss_rec, test_auc  #

for batch_spikes in spike_recordings:
    print(batch_spikes)

# %%
input_size = 32 #resize of mnist data (optional)

#setup GPU
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# neuron and simulation parameters
spike_grad = surrogate.atan(alpha=2.0)  # alternate surrogate gradient fast_sigmoid(slope=25)

train_loss_rec = []
test_loss_rec = []
train_loss_record = []
test_loss_record = []
train_avg_loss_rec=[]
test_avg_loss_rec=[]

  # Synaptic current and membrane potential decay exponentially with rates of alpha and beta
alpha=0.9
beta_syn=0.0001
# beta_syn=0.9
beta =0.9

num_steps=5
latent_dim = 32 #dimension of latent layer (how compressed we want the information)
thresh=1    #spiking threshold (lower = more spikes are let through)
epochs=3
max_epoch=epochs

lr=0.0001
betas=(0.9, 0.999)
weight_decay=0.001

#-------------------Define Network and optimizer
net=SAE()
net = net.to(device)

optimizer = torch.optim.AdamW(net.parameters(),
                            lr=lr,
                            betas=betas,
                            weight_decay=weight_decay)



activation = {}
# def get_activation(name):
#     def hook(model, input, output):
#         activation[name] = output.detach()
#     return hook


def get_activation(name):
    def hook(model, input, output):
        if isinstance(output, tuple):
            activation[name] = [out.detach() for out in output]
        else:
            activation[name] = output.detach()
    return hook


# net.encoder[5].register_forward_hook(get_activation('encoder[5]'))


checkpoint_path = "Saved_Trained_Checkpoints/"
Output_Spikes = "Output_Spikes/"
Enc_syn_Spikes = "Enc_syn_Spikes/"
Intermediate_Lyrs = "Intermediate_Lyrs/"
epoch_activations_list = [] # Create a list to store activations for each epoch
epoch_activations = {}


# ///////////////////////////////////

# Define hook_layers and hook_names
hook_layers = [net.encoder[2], net.encoder[5], net.encoder[8], net.encoder[11], net.decoder[1], net.decoder[4], net.decoder[7], net.decoder[9]]
hook_names = ["Enc_Lk1", "Enc_syn1", "Enc_syn2", "Enc_Lk2", "Dec_Lk1", "Dec_syn1", "Dec_syn2", "Dec_Lk2"]

# Create an empty dictionary to store activations
epoch_activations = {}

# Register hooks for capturing activations
hooks = []
for i, layer in enumerate(hook_layers):
    hook_fn = get_activation(hook_names[i])
    hooks.append(layer.register_forward_hook(hook_fn))
# ----------------------------------------------------------------

# %% [markdown]
# ### Grid Search method

# %%
import os

# Define the range of std_dev and mean values to explore
stddev_num_intervals = 11  # Adjust the number of intervals as needed
std_dev_range = np.linspace(0, 0.5, stddev_num_intervals)  # Generate values from 0 to 1 with stddev_num_intervals intervals

mean_num_intervals = 6  # Adjust the number of intervals as needed
mean_range = np.linspace(0, 1, mean_num_intervals)  # Generate values from 0 to 1 with mean_num_intervals intervals

best_std_dev = None
best_mean = None
best_loss = float('inf')
best_accuracy = 0
best_train_loss = float('inf')
best_train_accuracy = 0

# Lists to store metrics
std_dev_values = []
mean_values = []
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

# Number of grid search iterations
num_iterations = stddev_num_intervals * mean_num_intervals  # One iteration per combination of std_dev and mean values

for std_dev in std_dev_range:
    for mean in mean_range:
        # Reset network and optimizer for each std_dev and mean value
        net = SAE().to(device)
        optimizer = torch.optim.AdamW(net.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=0.001)

        # Create a folder to save intermediate layers for the current std_dev and mean
        intermediate_layers_dir = f"Intermediate_Lyrs/std_dev_{std_dev}_mean_{mean}"
        os.makedirs(intermediate_layers_dir, exist_ok=True)
        print('\n--------------------------------------This shows the <std_dev> and <mean> have been changed --------------------------------------\n')

        # Run training and testing
        for e in range(epochs):
            train_loss, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en = train(net, train_loader, optimizer, e, std_dev, mean)

            test_loss, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en = test(net, test_loader, optimizer, e, std_dev, mean)

            # Save intermediate layers every 10 epochs
            if (e + 1) % 10 == 0:
                activations_path = f"{intermediate_layers_dir}/activations_epoch_{e + 1}.pkl"
                with open(activations_path, 'wb') as file:
                    pickle.dump(epoch_activations, file)

        # Evaluate performance with the current std_dev and mean based on the last epoch

        # Record metrics
        std_dev_values.append(std_dev)
        mean_values.append(mean)
        train_losses.append(train_loss.item())
        test_losses.append(test_loss.item())
        train_accuracies.append(train_accuracy[-1])
        test_accuracies.append(test_accuracy[-1])

        if test_loss.item() < best_loss and test_accuracy[-1] > best_accuracy:
            best_std_dev = std_dev
            best_mean = mean
            best_loss = test_loss.item()
            best_accuracy = test_accuracy[-1]
            best_train_loss = train_loss.item()
            best_train_accuracy = train_accuracy[-1]

        print('---------------------------------------------------------------------------------------\n')
        print(f"std_dev={std_dev}, mean={mean}, train_loss= {train_loss.item():.4f}, test_loss= {test_loss.item():.4f}, train_accuracy= {train_accuracy[-1]*100:.4f}%, test_accuracy= {test_accuracy[-1]*100:.4f}%")
        print('---------------------------------------------------------------------------------------\n')

print('\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n')
print(f"Best std_dev: {best_std_dev}, Best mean: {best_mean}, Best train_loss: {best_train_loss:.4f}, Best test_loss: {best_loss:.4f}, Best train_accuracy: {best_train_accuracy*100:.4f}%, Best test_accuracy: {best_accuracy*100:.4f}%")
print('\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n')


# ----------------------------------------------------------------------------------Plotting the results
plt.figure(figsize=(12, 6))
# fig, axs = plt.subplots(2, 1, figsize=(6, 12))
font_size = 15
font = {'weight': 'bold', 'size': 22}
# Loss plot
plt.subplot(1, 2, 1)
plt.plot(mean_values, train_losses, label='Train Loss')
plt.plot(mean_values, test_losses, label='Test Loss')
plt.xlabel('std_dev', fontweight="bold", fontdict=font)
plt.ylabel('Loss', fontweight="bold", fontdict=font)
plt.title('Loss vs. std_dev', fontweight="bold", fontdict=font)
plt.tick_params(labelsize=font_size)
plt.legend(fontsize='large')

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(mean_values, train_accuracies, label='Train Accuracy')
plt.plot(mean_values, test_accuracies, label='Test Accuracy')
plt.xlabel('std_dev', fontweight="bold", fontdict=font)
plt.ylabel('Accuracy (%)', fontweight="bold", fontdict=font)
plt.title('Accuracy vs. std_dev', fontweight="bold", fontdict=font)
plt.tick_params(labelsize=font_size)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())  # Format y-axis as percentage
plt.legend(fontsize='large')

plt.tight_layout()
# plt.savefig('Loss&Acc_StdDev&Mean_GaussianNoise_input.png', dpi=300)  # dpi controls the quality (dots per inch)
plt.show()




plt.figure(figsize=(12, 6))
# fig, axs = plt.subplots(2, 1, figsize=(6, 12))
font_size = 15
font = {'weight': 'bold', 'size': 22}
# Loss plot
plt.subplot(1, 2, 1)
plt.plot(std_dev_values, train_losses, label='Train Loss')
plt.plot(std_dev_values, test_losses, label='Test Loss')
plt.xlabel('std_dev', fontweight="bold", fontdict=font)
plt.ylabel('Loss', fontweight="bold", fontdict=font)
plt.title('Loss vs. std_dev', fontweight="bold", fontdict=font)
plt.tick_params(labelsize=font_size)
plt.legend(fontsize='large')

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(std_dev_values, train_accuracies, label='Train Accuracy')
plt.plot(std_dev_values, test_accuracies, label='Test Accuracy')
plt.xlabel('std_dev', fontweight="bold", fontdict=font)
plt.ylabel('Accuracy (%)', fontweight="bold", fontdict=font)
plt.title('Accuracy vs. std_dev', fontweight="bold", fontdict=font)
plt.tick_params(labelsize=font_size)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())  # Format y-axis as percentage
plt.legend(fontsize='large')

plt.tight_layout()
# plt.savefig('Loss&Acc_StdDev&Mean_GaussianNoise_input.png', dpi=300)  # dpi controls the quality (dots per inch)
plt.show()


# --------------------------------------------------------------


from mpl_toolkits.mplot3d import Axes3D

# Create a 3D plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the points
ax.scatter(std_dev_values, mean_values, train_losses, c='r', marker='o', label='Train Loss')
ax.scatter(std_dev_values, mean_values, test_losses, c='b', marker='s', label='Test Loss')
ax.scatter(std_dev_values, mean_values, train_accuracies, c='g', marker='^', label='Train Accuracy')
ax.scatter(std_dev_values, mean_values, test_accuracies, c='y', marker='x', label='Test Accuracy')

# Set labels and title
ax.set_xlabel('std_dev', fontweight="bold", fontsize=15)
ax.set_ylabel('mean', fontweight="bold", fontsize=15)
ax.set_zlabel('Loss/Accuracy', fontweight="bold", fontsize=15)
ax.set_title('Loss/Accuracy vs. std_dev and mean', fontweight="bold", fontsize=18)

# Add a legend
ax.legend(fontsize='large')

# Show the plot
plt.show()


# --------------------------------------------
from mpl_toolkits.mplot3d import Axes3D

# Create a figure with two subplots (one for loss and one for accuracy)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot for loss
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax1.scatter(std_dev_values, mean_values, train_losses, c='r', marker='o', label='Train Loss')
ax1.scatter(std_dev_values, mean_values, test_losses, c='b', marker='s', label='Test Loss')
ax1.set_xlabel('std_dev', fontweight="bold", fontsize=12)
ax1.set_ylabel('mean', fontweight="bold", fontsize=12)
ax1.set_zlabel('Loss', fontweight="bold", fontsize=12)
ax1.set_title('Loss vs. std_dev and mean', fontweight="bold", fontsize=14)
ax1.legend()

# Plot for accuracy
ax2 = fig.add_subplot(1, 2, 2, projection='3d')
ax2.scatter(std_dev_values, mean_values, train_accuracies, c='g', marker='^', label='Train Accuracy')
ax2.scatter(std_dev_values, mean_values, test_accuracies, c='y', marker='x', label='Test Accuracy')
ax2.set_xlabel('std_dev', fontweight="bold", fontsize=12)
ax2.set_ylabel('mean', fontweight="bold", fontsize=12)
ax2.set_zlabel('Accuracy', fontweight="bold", fontsize=12)
ax2.set_title('Accuracy vs. std_dev and mean', fontweight="bold", fontsize=14)
ax2.legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------Epoch1/5 Test set ---------------
# Std_dev:0.4------Epoch [1/5] Average loss_test (epoch): 6.42906, Average Accuracy_test (epoch): -6.8538%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[2/5][0/12] Loss: 2.54903, BER: 0.33984, Accuracy: 40.8939%
# Std_dev:0.4------  Train__[2/5][1/12] Loss: 2.63741, BER: 0.33817, Accuracy: 40.1458%
# Std_dev:0.4------  Train__[2/5][2/12] Loss: 2.63346, BER: 0.33990, Accuracy: 40.1331%
# Std_dev:0.4------  Train__[2/5][3/12] Loss: 2.67116, BER: 0.33804, Accuracy: 39.8206%
# Std_dev:0.4------  Train__[2/5][4/12] Loss: 2.62784, BER: 0.34027, Accuracy: 40.1985%
# Std_dev:0.4------  Train__[2/5][5/12] Loss: 2.68840, BER: 0.34023, Accuracy: 39.6460%
# Std_dev:0.4------  Train__[2/5][6/12] Loss: 2.57640, BER: 0.34118, Accuracy: 40.5882%
# Std_dev:0.4------  Train__[2/5][7/12] Loss: 2.53633, BER: 0.33555, Accuracy: 41.0679%
# Std_dev:0.4------  Train__[2/5][8/12] Loss: 2.46488, BER: 0.34214, Accuracy: 41.4998%
# Std_dev:0.4------  Train__[2/5][9/12] Loss: 2.43412, BER: 0.33878, Accuracy: 41.8784%
# Std_dev:0.4------  Train__[2/5][10/12] Loss: 2.38766, BER: 0.33790, Accuracy: 42.2194%
# Std_dev:0.4------  Train__[2/5][11/12] Loss: 2.34696, BER: 0.33629, Accuracy: 42.5944%
# ----------------Epoch2/5 Train set ---------------
# Std_dev:0.4---- Epoch [2/5] Average loss (epoch): 2.54614, Average Accuracy (epoch): 40.8905%
# -------------------------------------
# Std_dev:0.4--- Test[2/5][0/12]  Loss(test): 6.08518, BER (test): 0.85921,  Accuracy(test): -5.0076%
# Std_dev:0.4--- Test[2/5][1/12]  Loss(test): 6.15131, BER (test): 0.85843,  Accuracy(test): -5.3242%
# Std_dev:0.4--- Test[2/5][2/12]  Loss(test): 6.08938, BER (test): 0.86032,  Accuracy(test): -5.0612%
# Std_dev:0.4--- Test[2/5][3/12]  Loss(test): 6.09524, BER (test): 0.85626,  Accuracy(test): -4.8209%
# Std_dev:0.4--- Test[2/5][4/12]  Loss(test): 6.12550, BER (test): 0.85702,  Accuracy(test): -5.0606%
# Std_dev:0.4--- Test[2/5][5/12]  Loss(test): 6.12164, BER (test): 0.85563,  Accuracy(test): -4.9299%
# Std_dev:0.4--- Test[2/5][6/12]  Loss(test): 6.09420, BER (test): 0.85694,  Accuracy(test): -4.9413%
# Std_dev:0.4--- Test[2/5][7/12]  Loss(test): 6.15504, BER (test): 0.85803,  Accuracy(test): -5.2898%
# Std_dev:0.4--- Test[2/5][8/12]  Loss(test): 6.13152, BER (test): 0.85430,  Accuracy(test): -4.9749%
# Std_dev:0.4--- Test[2/5][9/12]  Loss(test): 6.08715, BER (test): 0.84968,  Accuracy(test): -4.5051%
# Std_dev:0.4--- Test[2/5][10/12]  Loss(test): 6.11666, BER (test): 0.85775,  Accuracy(test): -5.0647%
# Std_dev:0.4--- Test[2/5][11/12]  Loss(test): 6.11534, BER (test): 0.85206,  Accuracy(test): -4.7815%
# ----------------Epoch2/5 Test set ---------------
# Std_dev:0.4------Epoch [2/5] Average loss_test (epoch): 6.11401, Average Accuracy_test (epoch): -4.9801%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[3/5][0/12] Loss: 2.36515, BER: 0.33876, Accuracy: 42.4496%
# Std_dev:0.4------  Train__[3/5][1/12] Loss: 2.37749, BER: 0.33749, Accuracy: 42.3877%
# Std_dev:0.4------  Train__[3/5][2/12] Loss: 2.44441, BER: 0.34016, Accuracy: 41.7791%
# Std_dev:0.4------  Train__[3/5][3/12] Loss: 2.53109, BER: 0.34315, Accuracy: 41.0082%
# Std_dev:0.4------  Train__[3/5][4/12] Loss: 2.57196, BER: 0.34666, Accuracy: 40.5940%
# Std_dev:0.4------  Train__[3/5][5/12] Loss: 2.63633, BER: 0.34494, Accuracy: 39.9793%
# Std_dev:0.4------  Train__[3/5][6/12] Loss: 2.64981, BER: 0.34482, Accuracy: 39.9384%
# Std_dev:0.4------  Train__[3/5][7/12] Loss: 2.68566, BER: 0.34761, Accuracy: 39.5951%
# Std_dev:0.4------  Train__[3/5][8/12] Loss: 2.68293, BER: 0.34597, Accuracy: 39.7166%
# Std_dev:0.4------  Train__[3/5][9/12] Loss: 2.63430, BER: 0.34581, Accuracy: 40.1015%
# Std_dev:0.4------  Train__[3/5][10/12] Loss: 2.60524, BER: 0.34468, Accuracy: 40.4290%
# Std_dev:0.4------  Train__[3/5][11/12] Loss: 2.51285, BER: 0.34545, Accuracy: 41.2356%
# ----------------Epoch3/5 Train set ---------------
# Std_dev:0.4---- Epoch [3/5] Average loss (epoch): 2.55810, Average Accuracy (epoch): 40.7678%
# -------------------------------------
# Std_dev:0.4--- Test[3/5][0/12]  Loss(test): 5.97512, BER (test): 0.84394,  Accuracy(test): -3.0412%
# Std_dev:0.4--- Test[3/5][1/12]  Loss(test): 5.99762, BER (test): 0.84109,  Accuracy(test): -2.9699%
# Std_dev:0.4--- Test[3/5][2/12]  Loss(test): 5.97686, BER (test): 0.84706,  Accuracy(test): -3.2766%
# Std_dev:0.4--- Test[3/5][3/12]  Loss(test): 5.97563, BER (test): 0.84037,  Accuracy(test): -2.7868%
# Std_dev:0.4--- Test[3/5][4/12]  Loss(test): 5.97572, BER (test): 0.84291,  Accuracy(test): -2.9675%
# Std_dev:0.4--- Test[3/5][5/12]  Loss(test): 5.95515, BER (test): 0.84479,  Accuracy(test): -2.9494%
# Std_dev:0.4--- Test[3/5][6/12]  Loss(test): 5.95863, BER (test): 0.84490,  Accuracy(test): -3.0648%
# Std_dev:0.4--- Test[3/5][7/12]  Loss(test): 5.95450, BER (test): 0.84977,  Accuracy(test): -3.3232%
# Std_dev:0.4--- Test[3/5][8/12]  Loss(test): 5.97233, BER (test): 0.83888,  Accuracy(test): -2.6972%
# Std_dev:0.4--- Test[3/5][9/12]  Loss(test): 5.92660, BER (test): 0.83836,  Accuracy(test): -2.5227%
# Std_dev:0.4--- Test[3/5][10/12]  Loss(test): 5.96012, BER (test): 0.84529,  Accuracy(test): -3.0807%
# Std_dev:0.4--- Test[3/5][11/12]  Loss(test): 5.93627, BER (test): 0.84232,  Accuracy(test): -2.7994%
# ----------------Epoch3/5 Test set ---------------
# Std_dev:0.4------Epoch [3/5] Average loss_test (epoch): 5.96371, Average Accuracy_test (epoch): -2.9566%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[4/5][0/12] Loss: 2.55805, BER: 0.34345, Accuracy: 40.8864%
# Std_dev:0.4------  Train__[4/5][1/12] Loss: 2.55176, BER: 0.34776, Accuracy: 40.8800%
# Std_dev:0.4------  Train__[4/5][2/12] Loss: 2.54963, BER: 0.34517, Accuracy: 40.9638%
# Std_dev:0.4------  Train__[4/5][3/12] Loss: 2.56959, BER: 0.34902, Accuracy: 40.7197%
# Std_dev:0.4------  Train__[4/5][4/12] Loss: 2.60091, BER: 0.34823, Accuracy: 40.5004%
# Std_dev:0.4------  Train__[4/5][5/12] Loss: 2.59873, BER: 0.34814, Accuracy: 40.5234%
# Std_dev:0.4------  Train__[4/5][6/12] Loss: 2.60659, BER: 0.34641, Accuracy: 40.4744%
# Std_dev:0.4------  Train__[4/5][7/12] Loss: 2.62059, BER: 0.34743, Accuracy: 40.3394%
# Std_dev:0.4------  Train__[4/5][8/12] Loss: 2.70976, BER: 0.34932, Accuracy: 39.5710%
# Std_dev:0.4------  Train__[4/5][9/12] Loss: 2.64967, BER: 0.34780, Accuracy: 40.0791%
# Std_dev:0.4------  Train__[4/5][10/12] Loss: 2.58094, BER: 0.34957, Accuracy: 40.8092%
# Std_dev:0.4------  Train__[4/5][11/12] Loss: 2.64521, BER: 0.35094, Accuracy: 40.1725%
# ----------------Epoch4/5 Train set ---------------
# Std_dev:0.4---- Epoch [4/5] Average loss (epoch): 2.60345, Average Accuracy (epoch): 40.4933%
# -------------------------------------
# Std_dev:0.4--- Test[4/5][0/12]  Loss(test): 5.81985, BER (test): 0.82291,  Accuracy(test): 0.0012%
# Std_dev:0.4--- Test[4/5][1/12]  Loss(test): 5.83933, BER (test): 0.82383,  Accuracy(test): -0.2486%
# Std_dev:0.4--- Test[4/5][2/12]  Loss(test): 5.82719, BER (test): 0.82429,  Accuracy(test): -0.1844%
# Std_dev:0.4--- Test[4/5][3/12]  Loss(test): 5.80485, BER (test): 0.82015,  Accuracy(test): 0.2807%
# Std_dev:0.4--- Test[4/5][4/12]  Loss(test): 5.81662, BER (test): 0.82437,  Accuracy(test): -0.1313%
# Std_dev:0.4--- Test[4/5][5/12]  Loss(test): 5.81453, BER (test): 0.82645,  Accuracy(test): -0.3381%
# Std_dev:0.4--- Test[4/5][6/12]  Loss(test): 5.83126, BER (test): 0.82257,  Accuracy(test): -0.1805%
# Std_dev:0.4--- Test[4/5][7/12]  Loss(test): 5.83318, BER (test): 0.82533,  Accuracy(test): -0.2932%
# Std_dev:0.4--- Test[4/5][8/12]  Loss(test): 5.81658, BER (test): 0.82174,  Accuracy(test): 0.0457%
# Std_dev:0.4--- Test[4/5][9/12]  Loss(test): 5.79124, BER (test): 0.81678,  Accuracy(test): 0.3736%
# Std_dev:0.4--- Test[4/5][10/12]  Loss(test): 5.82458, BER (test): 0.82227,  Accuracy(test): -0.0525%
# Std_dev:0.4--- Test[4/5][11/12]  Loss(test): 5.79044, BER (test): 0.81862,  Accuracy(test): 0.3445%
# ----------------Epoch4/5 Test set ---------------
# Std_dev:0.4------Epoch [4/5] Average loss_test (epoch): 5.81747, Average Accuracy_test (epoch): -0.0319%
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
#
# std_dev=0.4, mean=0.6000000000000001, train_loss= 2.6452, test_loss= 5.7904, train_accuracy= 40.1725%, test_accuracy= 0.3445%
# ---------------------------------------------------------------------------------------
#
#
# --------------------------------------This shows the <std_dev> and <mean> have been changed --------------------------------------
#
# Std_dev:0.4------  Train__[0/5][0/12] Loss: 1.26192, BER: 0.18659, Accuracy: 61.1372%
# Std_dev:0.4------  Train__[0/5][1/12] Loss: 1.24962, BER: 0.18569, Accuracy: 61.3164%
# Std_dev:0.4------  Train__[0/5][2/12] Loss: 1.26609, BER: 0.18566, Accuracy: 61.0204%
# Std_dev:0.4------  Train__[0/5][3/12] Loss: 1.26812, BER: 0.18534, Accuracy: 61.0390%
# Std_dev:0.4------  Train__[0/5][4/12] Loss: 1.26654, BER: 0.18441, Accuracy: 61.0588%
# Std_dev:0.4------  Train__[0/5][5/12] Loss: 1.26085, BER: 0.18579, Accuracy: 61.1653%
# Std_dev:0.4------  Train__[0/5][6/12] Loss: 1.23711, BER: 0.18816, Accuracy: 61.4722%
# Std_dev:0.4------  Train__[0/5][7/12] Loss: 1.26058, BER: 0.18626, Accuracy: 61.0997%
# Std_dev:0.4------  Train__[0/5][8/12] Loss: 1.26183, BER: 0.18713, Accuracy: 61.0889%
# Std_dev:0.4------  Train__[0/5][9/12] Loss: 1.26506, BER: 0.18664, Accuracy: 61.0443%
# Std_dev:0.4------  Train__[0/5][10/12] Loss: 1.27203, BER: 0.18488, Accuracy: 60.9372%
# Std_dev:0.4------  Train__[0/5][11/12] Loss: 1.24943, BER: 0.18721, Accuracy: 61.2833%
# ----------------Epoch0/5 Train set ---------------
# Std_dev:0.4---- Epoch [0/5] Average loss (epoch): 1.25993, Average Accuracy (epoch): 61.1386%
# -------------------------------------
# Std_dev:0.4--- Test[0/5][0/12]  Loss(test): 2.92890, BER (test): 0.86996,  Accuracy(test): 27.4557%
# Std_dev:0.4--- Test[0/5][1/12]  Loss(test): 2.93222, BER (test): 0.87132,  Accuracy(test): 27.3736%
# Std_dev:0.4--- Test[0/5][2/12]  Loss(test): 2.93460, BER (test): 0.87165,  Accuracy(test): 27.3379%
# Std_dev:0.4--- Test[0/5][3/12]  Loss(test): 2.91955, BER (test): 0.86891,  Accuracy(test): 27.6197%
# Std_dev:0.4--- Test[0/5][4/12]  Loss(test): 2.92845, BER (test): 0.87017,  Accuracy(test): 27.4617%
# Std_dev:0.4--- Test[0/5][5/12]  Loss(test): 2.92000, BER (test): 0.86874,  Accuracy(test): 27.6135%
# Std_dev:0.4--- Test[0/5][6/12]  Loss(test): 2.92183, BER (test): 0.86833,  Accuracy(test): 27.5948%
# Std_dev:0.4--- Test[0/5][7/12]  Loss(test): 2.93422, BER (test): 0.87181,  Accuracy(test): 27.3485%
# Std_dev:0.4--- Test[0/5][8/12]  Loss(test): 2.92018, BER (test): 0.86723,  Accuracy(test): 27.6302%
# Std_dev:0.4--- Test[0/5][9/12]  Loss(test): 2.90074, BER (test): 0.86237,  Accuracy(test): 28.0169%
# Std_dev:0.4--- Test[0/5][10/12]  Loss(test): 2.93045, BER (test): 0.86950,  Accuracy(test): 27.4521%
# Std_dev:0.4--- Test[0/5][11/12]  Loss(test): 2.91253, BER (test): 0.86580,  Accuracy(test): 27.7703%
# ----------------Epoch0/5 Test set ---------------
# Std_dev:0.4------Epoch [0/5] Average loss_test (epoch): 2.92364, Average Accuracy_test (epoch): 27.5562%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[1/5][0/12] Loss: 1.27153, BER: 0.18533, Accuracy: 60.9818%
# Std_dev:0.4------  Train__[1/5][1/12] Loss: 1.26545, BER: 0.18685, Accuracy: 61.0993%
# Std_dev:0.4------  Train__[1/5][2/12] Loss: 1.42235, BER: 0.19306, Accuracy: 59.4258%
# Std_dev:0.4------  Train__[1/5][3/12] Loss: 1.43408, BER: 0.19392, Accuracy: 59.2974%
# Std_dev:0.4------  Train__[1/5][4/12] Loss: 1.54481, BER: 0.20121, Accuracy: 58.0246%
# Std_dev:0.4------  Train__[1/5][5/12] Loss: 1.64114, BER: 0.20537, Accuracy: 57.1194%
# Std_dev:0.4------  Train__[1/5][6/12] Loss: 1.66390, BER: 0.20638, Accuracy: 56.9415%
# Std_dev:0.4------  Train__[1/5][7/12] Loss: 1.63747, BER: 0.20524, Accuracy: 57.1368%
# Std_dev:0.4------  Train__[1/5][8/12] Loss: 1.61904, BER: 0.20429, Accuracy: 57.3644%
# Std_dev:0.4------  Train__[1/5][9/12] Loss: 1.54470, BER: 0.20015, Accuracy: 58.1818%
# Std_dev:0.4------  Train__[1/5][10/12] Loss: 1.47248, BER: 0.19673, Accuracy: 58.8895%
# Std_dev:0.4------  Train__[1/5][11/12] Loss: 1.41504, BER: 0.19468, Accuracy: 59.4372%
# ----------------Epoch1/5 Train set ---------------
# Std_dev:0.4---- Epoch [1/5] Average loss (epoch): 1.49433, Average Accuracy (epoch): 58.6583%
# -------------------------------------
# Std_dev:0.4--- Test[1/5][0/12]  Loss(test): 2.96220, BER (test): 0.86996,  Accuracy(test): 27.0585%
# Std_dev:0.4--- Test[1/5][1/12]  Loss(test): 2.96557, BER (test): 0.87132,  Accuracy(test): 26.9750%
# Std_dev:0.4--- Test[1/5][2/12]  Loss(test): 2.96796, BER (test): 0.87165,  Accuracy(test): 26.9390%
# Std_dev:0.4--- Test[1/5][3/12]  Loss(test): 2.95277, BER (test): 0.86891,  Accuracy(test): 27.2224%
# Std_dev:0.4--- Test[1/5][4/12]  Loss(test): 2.96174, BER (test): 0.87017,  Accuracy(test): 27.0644%
# Std_dev:0.4--- Test[1/5][5/12]  Loss(test): 2.95321, BER (test): 0.86874,  Accuracy(test): 27.2171%
# Std_dev:0.4--- Test[1/5][6/12]  Loss(test): 2.95506, BER (test): 0.86833,  Accuracy(test): 27.1982%
# Std_dev:0.4--- Test[1/5][7/12]  Loss(test): 2.96759, BER (test): 0.87181,  Accuracy(test): 26.9497%
# Std_dev:0.4--- Test[1/5][8/12]  Loss(test): 2.95334, BER (test): 0.86723,  Accuracy(test): 27.2366%
# Std_dev:0.4--- Test[1/5][9/12]  Loss(test): 2.93370, BER (test): 0.86237,  Accuracy(test): 27.6248%
# Std_dev:0.4--- Test[1/5][10/12]  Loss(test): 2.96373, BER (test): 0.86950,  Accuracy(test): 27.0566%
# Std_dev:0.4--- Test[1/5][11/12]  Loss(test): 2.94565, BER (test): 0.86580,  Accuracy(test): 27.3751%
# ----------------Epoch1/5 Test set ---------------
# Std_dev:0.4------Epoch [1/5] Average loss_test (epoch): 2.95688, Average Accuracy_test (epoch): 27.1598%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[2/5][0/12] Loss: 1.42844, BER: 0.19430, Accuracy: 59.2919%
# Std_dev:0.4------  Train__[2/5][1/12] Loss: 1.36392, BER: 0.19219, Accuracy: 59.9966%
# Std_dev:0.4------  Train__[2/5][2/12] Loss: 1.34982, BER: 0.19167, Accuracy: 60.1461%
# Std_dev:0.4------  Train__[2/5][3/12] Loss: 1.38924, BER: 0.19373, Accuracy: 59.6556%
# Std_dev:0.4------  Train__[2/5][4/12] Loss: 1.41771, BER: 0.19499, Accuracy: 59.3427%
# Std_dev:0.4------  Train__[2/5][5/12] Loss: 1.39422, BER: 0.19261, Accuracy: 59.5707%
# Std_dev:0.4------  Train__[2/5][6/12] Loss: 1.41924, BER: 0.19473, Accuracy: 59.2428%
# Std_dev:0.4------  Train__[2/5][7/12] Loss: 1.42654, BER: 0.19681, Accuracy: 59.1794%
# Std_dev:0.4------  Train__[2/5][8/12] Loss: 1.45485, BER: 0.19610, Accuracy: 58.7123%
# Std_dev:0.4------  Train__[2/5][9/12] Loss: 1.49237, BER: 0.19675, Accuracy: 58.2627%
# Std_dev:0.4------  Train__[2/5][10/12] Loss: 1.54844, BER: 0.20597, Accuracy: 57.7343%
# Std_dev:0.4------  Train__[2/5][11/12] Loss: 1.53366, BER: 0.20457, Accuracy: 57.7424%
# ----------------Epoch2/5 Train set ---------------
# Std_dev:0.4---- Epoch [2/5] Average loss (epoch): 1.43487, Average Accuracy (epoch): 59.0731%
# -------------------------------------
# Std_dev:0.4--- Test[2/5][0/12]  Loss(test): 2.99631, BER (test): 0.86985,  Accuracy(test): 26.6645%
# Std_dev:0.4--- Test[2/5][1/12]  Loss(test): 2.99818, BER (test): 0.87132,  Accuracy(test): 26.5869%
# Std_dev:0.4--- Test[2/5][2/12]  Loss(test): 3.00059, BER (test): 0.87165,  Accuracy(test): 26.5506%
# Std_dev:0.4--- Test[2/5][3/12]  Loss(test): 2.98672, BER (test): 0.86879,  Accuracy(test): 26.8288%
# Std_dev:0.4--- Test[2/5][4/12]  Loss(test): 2.99429, BER (test): 0.87017,  Accuracy(test): 26.6774%
# Std_dev:0.4--- Test[2/5][5/12]  Loss(test): 2.98568, BER (test): 0.86874,  Accuracy(test): 26.8312%
# Std_dev:0.4--- Test[2/5][6/12]  Loss(test): 2.98902, BER (test): 0.86821,  Accuracy(test): 26.8053%
# Std_dev:0.4--- Test[2/5][7/12]  Loss(test): 3.00021, BER (test): 0.87181,  Accuracy(test): 26.5614%
# Std_dev:0.4--- Test[2/5][8/12]  Loss(test): 2.98576, BER (test): 0.86723,  Accuracy(test): 26.8534%
# Std_dev:0.4--- Test[2/5][9/12]  Loss(test): 2.96742, BER (test): 0.86225,  Accuracy(test): 27.2361%
# Std_dev:0.4--- Test[2/5][10/12]  Loss(test): 2.99627, BER (test): 0.86950,  Accuracy(test): 26.6714%
# Std_dev:0.4--- Test[2/5][11/12]  Loss(test): 2.97803, BER (test): 0.86580,  Accuracy(test): 26.9903%
# ----------------Epoch2/5 Test set ---------------
# Std_dev:0.4------Epoch [2/5] Average loss_test (epoch): 2.98987, Average Accuracy_test (epoch): 26.7714%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[3/5][0/12] Loss: 1.56530, BER: 0.20478, Accuracy: 57.3808%
# Std_dev:0.4------  Train__[3/5][1/12] Loss: 1.46299, BER: 0.20287, Accuracy: 58.6165%
# Std_dev:0.4------  Train__[3/5][2/12] Loss: 1.55156, BER: 0.20566, Accuracy: 57.5109%
# Std_dev:0.4------  Train__[3/5][3/12] Loss: 1.44748, BER: 0.20061, Accuracy: 58.7713%
# Std_dev:0.4------  Train__[3/5][4/12] Loss: 1.46808, BER: 0.20215, Accuracy: 58.5461%
# Std_dev:0.4------  Train__[3/5][5/12] Loss: 1.41850, BER: 0.20008, Accuracy: 59.1291%
# Std_dev:0.4------  Train__[3/5][6/12] Loss: 1.44738, BER: 0.20319, Accuracy: 58.8114%
# Std_dev:0.4------  Train__[3/5][7/12] Loss: 1.39450, BER: 0.20035, Accuracy: 59.4265%
# Std_dev:0.4------  Train__[3/5][8/12] Loss: 1.43598, BER: 0.20196, Accuracy: 58.8513%
# Std_dev:0.4------  Train__[3/5][9/12] Loss: 1.41428, BER: 0.20158, Accuracy: 59.1499%
# Std_dev:0.4------  Train__[3/5][10/12] Loss: 1.42793, BER: 0.20163, Accuracy: 58.9404%
# Std_dev:0.4------  Train__[3/5][11/12] Loss: 1.44411, BER: 0.20528, Accuracy: 58.7229%
# ----------------Epoch3/5 Train set ---------------
# Std_dev:0.4---- Epoch [3/5] Average loss (epoch): 1.45651, Average Accuracy (epoch): 58.6548%
# -------------------------------------
# Std_dev:0.4--- Test[3/5][0/12]  Loss(test): 3.02714, BER (test): 0.86986,  Accuracy(test): 26.2965%
# Std_dev:0.4--- Test[3/5][1/12]  Loss(test): 3.03061, BER (test): 0.87122,  Accuracy(test): 26.2103%
# Std_dev:0.4--- Test[3/5][2/12]  Loss(test): 3.03191, BER (test): 0.87165,  Accuracy(test): 26.1793%
# Std_dev:0.4--- Test[3/5][3/12]  Loss(test): 3.01643, BER (test): 0.86891,  Accuracy(test): 26.4656%
# Std_dev:0.4--- Test[3/5][4/12]  Loss(test): 3.02894, BER (test): 0.86985,  Accuracy(test): 26.2911%
# Std_dev:0.4--- Test[3/5][5/12]  Loss(test): 3.01685, BER (test): 0.86874,  Accuracy(test): 26.4621%
# Std_dev:0.4--- Test[3/5][6/12]  Loss(test): 3.01987, BER (test): 0.86822,  Accuracy(test): 26.4371%
# Std_dev:0.4--- Test[3/5][7/12]  Loss(test): 3.03267, BER (test): 0.87171,  Accuracy(test): 26.1846%
# Std_dev:0.4--- Test[3/5][8/12]  Loss(test): 3.01689, BER (test): 0.86723,  Accuracy(test): 26.4869%
# Std_dev:0.4--- Test[3/5][9/12]  Loss(test): 3.00028, BER (test): 0.86207,  Accuracy(test): 26.8604%
# Std_dev:0.4--- Test[3/5][10/12]  Loss(test): 3.02876, BER (test): 0.86943,  Accuracy(test): 26.2949%
# Std_dev:0.4--- Test[3/5][11/12]  Loss(test): 3.01256, BER (test): 0.86550,  Accuracy(test): 26.6055%
# ----------------Epoch3/5 Test set ---------------
# Std_dev:0.4------Epoch [3/5] Average loss_test (epoch): 3.02191, Average Accuracy_test (epoch): 26.3979%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[4/5][0/12] Loss: 1.47017, BER: 0.20422, Accuracy: 58.3416%
# Std_dev:0.4------  Train__[4/5][1/12] Loss: 1.41832, BER: 0.20194, Accuracy: 59.0007%
# Std_dev:0.4------  Train__[4/5][2/12] Loss: 1.46211, BER: 0.20559, Accuracy: 58.4608%
# Std_dev:0.4------  Train__[4/5][3/12] Loss: 1.51271, BER: 0.20980, Accuracy: 57.8287%
# Std_dev:0.4------  Train__[4/5][4/12] Loss: 1.52410, BER: 0.21228, Accuracy: 57.6501%
# Std_dev:0.4------  Train__[4/5][5/12] Loss: 1.57357, BER: 0.21384, Accuracy: 57.0659%
# Std_dev:0.4------  Train__[4/5][6/12] Loss: 1.56638, BER: 0.21823, Accuracy: 57.0394%
# Std_dev:0.4------  Train__[4/5][7/12] Loss: 1.51453, BER: 0.21224, Accuracy: 57.7145%
# Std_dev:0.4------  Train__[4/5][8/12] Loss: 1.56102, BER: 0.21378, Accuracy: 57.1110%
# Std_dev:0.4------  Train__[4/5][9/12] Loss: 1.47683, BER: 0.20650, Accuracy: 58.1480%
# Std_dev:0.4------  Train__[4/5][10/12] Loss: 1.48649, BER: 0.21052, Accuracy: 58.0655%
# Std_dev:0.4------  Train__[4/5][11/12] Loss: 1.48847, BER: 0.21077, Accuracy: 58.0507%
# ----------------Epoch4/5 Train set ---------------
# Std_dev:0.4---- Epoch [4/5] Average loss (epoch): 1.50456, Average Accuracy (epoch): 57.8731%
# -------------------------------------
# Std_dev:0.4--- Test[4/5][0/12]  Loss(test): 3.06536, BER (test): 0.86953,  Accuracy(test): 25.8753%
# Std_dev:0.4--- Test[4/5][1/12]  Loss(test): 3.06583, BER (test): 0.87098,  Accuracy(test): 25.8197%
# Std_dev:0.4--- Test[4/5][2/12]  Loss(test): 3.06655, BER (test): 0.87141,  Accuracy(test): 25.7935%
# Std_dev:0.4--- Test[4/5][3/12]  Loss(test): 3.05411, BER (test): 0.86851,  Accuracy(test): 26.0617%
# Std_dev:0.4--- Test[4/5][4/12]  Loss(test): 3.06757, BER (test): 0.86959,  Accuracy(test): 25.8692%
# Std_dev:0.4--- Test[4/5][5/12]  Loss(test): 3.05370, BER (test): 0.86849,  Accuracy(test): 26.0582%
# Std_dev:0.4--- Test[4/5][6/12]  Loss(test): 3.05632, BER (test): 0.86798,  Accuracy(test): 26.0355%
# Std_dev:0.4--- Test[4/5][7/12]  Loss(test): 3.06617, BER (test): 0.87168,  Accuracy(test): 25.7993%
# Std_dev:0.4--- Test[4/5][8/12]  Loss(test): 3.05353, BER (test): 0.86695,  Accuracy(test): 26.0847%
# Std_dev:0.4--- Test[4/5][9/12]  Loss(test): 3.03370, BER (test): 0.86204,  Accuracy(test): 26.4800%
# Std_dev:0.4--- Test[4/5][10/12]  Loss(test): 3.06750, BER (test): 0.86898,  Accuracy(test): 25.8807%
# Std_dev:0.4--- Test[4/5][11/12]  Loss(test): 3.04320, BER (test): 0.86559,  Accuracy(test): 26.2412%
# ----------------Epoch4/5 Test set ---------------
# Std_dev:0.4------Epoch [4/5] Average loss_test (epoch): 3.05780, Average Accuracy_test (epoch): 25.9999%
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
#
# std_dev=0.4, mean=0.8, train_loss= 1.4885, test_loss= 3.0432, train_accuracy= 58.0507%, test_accuracy= 26.2412%
# ---------------------------------------------------------------------------------------
#
#
# --------------------------------------This shows the <std_dev> and <mean> have been changed --------------------------------------
#
# Std_dev:0.4------  Train__[0/5][0/12] Loss: 3.82244, BER: 0.91380, Accuracy: 25.7851%
# Std_dev:0.4------  Train__[0/5][1/12] Loss: 3.87549, BER: 0.91445, Accuracy: 25.2841%
# Std_dev:0.4------  Train__[0/5][2/12] Loss: 3.80971, BER: 0.91318, Accuracy: 25.9460%
# Std_dev:0.4------  Train__[0/5][3/12] Loss: 3.84047, BER: 0.91397, Accuracy: 25.6401%
# Std_dev:0.4------  Train__[0/5][4/12] Loss: 3.77252, BER: 0.91402, Accuracy: 26.2823%
# Std_dev:0.4------  Train__[0/5][5/12] Loss: 3.81753, BER: 0.91382, Accuracy: 25.9213%
# Std_dev:0.4------  Train__[0/5][6/12] Loss: 3.81627, BER: 0.91474, Accuracy: 25.8573%
# Std_dev:0.4------  Train__[0/5][7/12] Loss: 3.77650, BER: 0.91312, Accuracy: 26.2382%
# Std_dev:0.4------  Train__[0/5][8/12] Loss: 3.83429, BER: 0.91207, Accuracy: 25.8205%
# Std_dev:0.4------  Train__[0/5][9/12] Loss: 3.85330, BER: 0.90867, Accuracy: 25.6712%
# Std_dev:0.4------  Train__[0/5][10/12] Loss: 4.04813, BER: 0.89276, Accuracy: 24.1580%
# Std_dev:0.4------  Train__[0/5][11/12] Loss: 4.22716, BER: 0.86778, Accuracy: 22.9960%
# ----------------Epoch0/5 Train set ---------------
# Std_dev:0.4---- Epoch [0/5] Average loss (epoch): 3.87448, Average Accuracy (epoch): 25.4667%
# -------------------------------------
# Std_dev:0.4--- Test[0/5][0/12]  Loss(test): 2.17852, BER (test): 0.22890,  Accuracy(test): 48.9939%
# Std_dev:0.4--- Test[0/5][1/12]  Loss(test): 2.21273, BER (test): 0.23007,  Accuracy(test): 48.7357%
# Std_dev:0.4--- Test[0/5][2/12]  Loss(test): 2.21976, BER (test): 0.23037,  Accuracy(test): 48.7098%
# Std_dev:0.4--- Test[0/5][3/12]  Loss(test): 2.23509, BER (test): 0.23343,  Accuracy(test): 48.5402%
# Std_dev:0.4--- Test[0/5][4/12]  Loss(test): 2.14276, BER (test): 0.22335,  Accuracy(test): 49.2857%
# Std_dev:0.4--- Test[0/5][5/12]  Loss(test): 2.13160, BER (test): 0.22628,  Accuracy(test): 49.4512%
# Std_dev:0.4--- Test[0/5][6/12]  Loss(test): 2.02964, BER (test): 0.21994,  Accuracy(test): 50.2972%
# Std_dev:0.4--- Test[0/5][7/12]  Loss(test): 2.17869, BER (test): 0.22704,  Accuracy(test): 48.9927%
# Std_dev:0.4--- Test[0/5][8/12]  Loss(test): 2.00118, BER (test): 0.21902,  Accuracy(test): 50.4289%
# Std_dev:0.4--- Test[0/5][9/12]  Loss(test): 2.07928, BER (test): 0.22950,  Accuracy(test): 49.7926%
# Std_dev:0.4--- Test[0/5][10/12]  Loss(test): 2.25398, BER (test): 0.23452,  Accuracy(test): 48.2895%
# Std_dev:0.4--- Test[0/5][11/12]  Loss(test): 2.13199, BER (test): 0.22927,  Accuracy(test): 49.3702%
# ----------------Epoch0/5 Test set ---------------
# Std_dev:0.4------Epoch [0/5] Average loss_test (epoch): 2.14960, Average Accuracy_test (epoch): 49.2406%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[1/5][0/12] Loss: 4.50779, BER: 0.82591, Accuracy: 21.0421%
# Std_dev:0.4------  Train__[1/5][1/12] Loss: 4.76159, BER: 0.78497, Accuracy: 19.0876%
# Std_dev:0.4------  Train__[1/5][2/12] Loss: 4.73369, BER: 0.76732, Accuracy: 19.4979%
# Std_dev:0.4------  Train__[1/5][3/12] Loss: 4.73513, BER: 0.76844, Accuracy: 19.4532%
# Std_dev:0.4------  Train__[1/5][4/12] Loss: 4.59353, BER: 0.78857, Accuracy: 20.4475%
# Std_dev:0.4------  Train__[1/5][5/12] Loss: 4.42097, BER: 0.80845, Accuracy: 21.7912%
# Std_dev:0.4------  Train__[1/5][6/12] Loss: 4.27062, BER: 0.83922, Accuracy: 22.9295%
# Std_dev:0.4------  Train__[1/5][7/12] Loss: 4.15409, BER: 0.84975, Accuracy: 23.8057%
# Std_dev:0.4------  Train__[1/5][8/12] Loss: 4.05079, BER: 0.86845, Accuracy: 24.5814%
# Std_dev:0.4------  Train__[1/5][9/12] Loss: 3.96228, BER: 0.87789, Accuracy: 25.1581%
# Std_dev:0.4------  Train__[1/5][10/12] Loss: 3.93378, BER: 0.89190, Accuracy: 25.2523%
# Std_dev:0.4------  Train__[1/5][11/12] Loss: 3.92211, BER: 0.88482, Accuracy: 25.4686%
# ----------------Epoch1/5 Train set ---------------
# Std_dev:0.4---- Epoch [1/5] Average loss (epoch): 4.33720, Average Accuracy (epoch): 22.3763%
# -------------------------------------
# Std_dev:0.4--- Test[1/5][0/12]  Loss(test): 0.95276, BER (test): 0.14300,  Accuracy(test): 59.2247%
# Std_dev:0.4--- Test[1/5][1/12]  Loss(test): 0.94041, BER (test): 0.14059,  Accuracy(test): 59.3547%
# Std_dev:0.4--- Test[1/5][2/12]  Loss(test): 0.92880, BER (test): 0.13879,  Accuracy(test): 59.4316%
# Std_dev:0.4--- Test[1/5][3/12]  Loss(test): 0.95319, BER (test): 0.14425,  Accuracy(test): 59.2743%
# Std_dev:0.4--- Test[1/5][4/12]  Loss(test): 0.93130, BER (test): 0.14049,  Accuracy(test): 59.4183%
# Std_dev:0.4--- Test[1/5][5/12]  Loss(test): 0.91210, BER (test): 0.14032,  Accuracy(test): 59.6207%
# Std_dev:0.4--- Test[1/5][6/12]  Loss(test): 0.93274, BER (test): 0.14263,  Accuracy(test): 59.4247%
# Std_dev:0.4--- Test[1/5][7/12]  Loss(test): 0.95245, BER (test): 0.14125,  Accuracy(test): 59.2397%
# Std_dev:0.4--- Test[1/5][8/12]  Loss(test): 0.92681, BER (test): 0.14264,  Accuracy(test): 59.4010%
# Std_dev:0.4--- Test[1/5][9/12]  Loss(test): 0.91043, BER (test): 0.14609,  Accuracy(test): 59.6033%
# Std_dev:0.4--- Test[1/5][10/12]  Loss(test): 0.95281, BER (test): 0.14282,  Accuracy(test): 59.1374%
# Std_dev:0.4--- Test[1/5][11/12]  Loss(test): 0.95272, BER (test): 0.14685,  Accuracy(test): 59.2423%
# ----------------Epoch1/5 Test set ---------------
# Std_dev:0.4------Epoch [1/5] Average loss_test (epoch): 0.93721, Average Accuracy_test (epoch): 59.3644%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[2/5][0/12] Loss: 3.93602, BER: 0.87367, Accuracy: 25.5769%
# Std_dev:0.4------  Train__[2/5][1/12] Loss: 3.95379, BER: 0.86108, Accuracy: 25.5492%
# Std_dev:0.4------  Train__[2/5][2/12] Loss: 4.08537, BER: 0.83863, Accuracy: 24.5496%
# Std_dev:0.4------  Train__[2/5][3/12] Loss: 4.15178, BER: 0.80448, Accuracy: 24.3448%
# Std_dev:0.4------  Train__[2/5][4/12] Loss: 4.24178, BER: 0.76936, Accuracy: 23.7693%
# Std_dev:0.4------  Train__[2/5][5/12] Loss: 4.30952, BER: 0.74655, Accuracy: 23.4377%
# Std_dev:0.4------  Train__[2/5][6/12] Loss: 4.28557, BER: 0.73709, Accuracy: 23.6147%
# Std_dev:0.4------  Train__[2/5][7/12] Loss: 4.31034, BER: 0.72829, Accuracy: 23.5705%
# Std_dev:0.4------  Train__[2/5][8/12] Loss: 4.31214, BER: 0.71931, Accuracy: 23.6501%
# Std_dev:0.4------  Train__[2/5][9/12] Loss: 4.23949, BER: 0.72591, Accuracy: 24.0654%
# Std_dev:0.4------  Train__[2/5][10/12] Loss: 4.07063, BER: 0.75555, Accuracy: 25.3041%
# Std_dev:0.4------  Train__[2/5][11/12] Loss: 4.02688, BER: 0.76832, Accuracy: 25.5197%
# ----------------Epoch2/5 Train set ---------------
# Std_dev:0.4---- Epoch [2/5] Average loss (epoch): 4.16028, Average Accuracy (epoch): 24.4127%
# -------------------------------------
# Std_dev:0.4--- Test[2/5][0/12]  Loss(test): 1.21592, BER (test): 0.18106,  Accuracy(test): 56.2518%
# Std_dev:0.4--- Test[2/5][1/12]  Loss(test): 1.18703, BER (test): 0.17581,  Accuracy(test): 56.5634%
# Std_dev:0.4--- Test[2/5][2/12]  Loss(test): 1.23608, BER (test): 0.18168,  Accuracy(test): 56.0545%
# Std_dev:0.4--- Test[2/5][3/12]  Loss(test): 1.21605, BER (test): 0.18317,  Accuracy(test): 56.3058%
# Std_dev:0.4--- Test[2/5][4/12]  Loss(test): 1.19696, BER (test): 0.17702,  Accuracy(test): 56.4489%
# Std_dev:0.4--- Test[2/5][5/12]  Loss(test): 1.16145, BER (test): 0.17477,  Accuracy(test): 56.8346%
# Std_dev:0.4--- Test[2/5][6/12]  Loss(test): 1.19072, BER (test): 0.17961,  Accuracy(test): 56.5419%
# Std_dev:0.4--- Test[2/5][7/12]  Loss(test): 1.20211, BER (test): 0.17764,  Accuracy(test): 56.4078%
# Std_dev:0.4--- Test[2/5][8/12]  Loss(test): 1.15621, BER (test): 0.17519,  Accuracy(test): 56.8097%
# Std_dev:0.4--- Test[2/5][9/12]  Loss(test): 1.22098, BER (test): 0.18666,  Accuracy(test): 56.2217%
# Std_dev:0.4--- Test[2/5][10/12]  Loss(test): 1.21997, BER (test): 0.18077,  Accuracy(test): 56.1547%
# Std_dev:0.4--- Test[2/5][11/12]  Loss(test): 1.25732, BER (test): 0.19018,  Accuracy(test): 55.8857%
# ----------------Epoch2/5 Test set ---------------
# Std_dev:0.4------Epoch [2/5] Average loss_test (epoch): 1.20507, Average Accuracy_test (epoch): 56.3734%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[3/5][0/12] Loss: 3.93055, BER: 0.77931, Accuracy: 26.3439%
# Std_dev:0.4------  Train__[3/5][1/12] Loss: 3.95129, BER: 0.78797, Accuracy: 25.9581%
# Std_dev:0.4------  Train__[3/5][2/12] Loss: 3.91334, BER: 0.78038, Accuracy: 26.3683%
# Std_dev:0.4------  Train__[3/5][3/12] Loss: 3.86117, BER: 0.77602, Accuracy: 26.8819%
# Std_dev:0.4------  Train__[3/5][4/12] Loss: 3.94734, BER: 0.75876, Accuracy: 26.2778%
# Std_dev:0.4------  Train__[3/5][5/12] Loss: 3.95010, BER: 0.75941, Accuracy: 26.2525%
# Std_dev:0.4------  Train__[3/5][6/12] Loss: 3.87512, BER: 0.75518, Accuracy: 26.8955%
# Std_dev:0.4------  Train__[3/5][7/12] Loss: 3.95178, BER: 0.75249, Accuracy: 26.1868%
# Std_dev:0.4------  Train__[3/5][8/12] Loss: 3.92453, BER: 0.73447, Accuracy: 26.5937%
# Std_dev:0.4------  Train__[3/5][9/12] Loss: 3.89666, BER: 0.72863, Accuracy: 26.9209%
# Std_dev:0.4------  Train__[3/5][10/12] Loss: 3.93909, BER: 0.71442, Accuracy: 26.7136%
# Std_dev:0.4------  Train__[3/5][11/12] Loss: 3.93559, BER: 0.71273, Accuracy: 26.7653%
# ----------------Epoch3/5 Train set ---------------
# Std_dev:0.4---- Epoch [3/5] Average loss (epoch): 3.92305, Average Accuracy (epoch): 26.5132%
# -------------------------------------
# Std_dev:0.4--- Test[3/5][0/12]  Loss(test): 1.51881, BER (test): 0.23625,  Accuracy(test): 52.7472%
# Std_dev:0.4--- Test[3/5][1/12]  Loss(test): 1.52340, BER (test): 0.23489,  Accuracy(test): 52.7172%
# Std_dev:0.4--- Test[3/5][2/12]  Loss(test): 1.44279, BER (test): 0.22295,  Accuracy(test): 53.5199%
# Std_dev:0.4--- Test[3/5][3/12]  Loss(test): 1.44534, BER (test): 0.22418,  Accuracy(test): 53.5549%
# Std_dev:0.4--- Test[3/5][4/12]  Loss(test): 1.44660, BER (test): 0.22382,  Accuracy(test): 53.5060%
# Std_dev:0.4--- Test[3/5][5/12]  Loss(test): 1.38663, BER (test): 0.21786,  Accuracy(test): 54.1290%
# Std_dev:0.4--- Test[3/5][6/12]  Loss(test): 1.53672, BER (test): 0.24095,  Accuracy(test): 52.6101%
# Std_dev:0.4--- Test[3/5][7/12]  Loss(test): 1.44053, BER (test): 0.22316,  Accuracy(test): 53.5554%
# Std_dev:0.4--- Test[3/5][8/12]  Loss(test): 1.44412, BER (test): 0.22705,  Accuracy(test): 53.4821%
# Std_dev:0.4--- Test[3/5][9/12]  Loss(test): 1.49085, BER (test): 0.23960,  Accuracy(test): 53.0819%
# Std_dev:0.4--- Test[3/5][10/12]  Loss(test): 1.42601, BER (test): 0.22231,  Accuracy(test): 53.6529%
# Std_dev:0.4--- Test[3/5][11/12]  Loss(test): 1.47323, BER (test): 0.23344,  Accuracy(test): 53.2593%
# ----------------Epoch3/5 Test set ---------------
# Std_dev:0.4------Epoch [3/5] Average loss_test (epoch): 1.46459, Average Accuracy_test (epoch): 53.3180%
# -----------------------------------------------------------------------------------------
# Std_dev:0.4------  Train__[4/5][0/12] Loss: 3.89383, BER: 0.70467, Accuracy: 27.0576%
# Std_dev:0.4------  Train__[4/5][1/12] Loss: 3.91541, BER: 0.69873, Accuracy: 27.0459%
# Std_dev:0.4------  Train__[4/5][2/12] Loss: 3.97015, BER: 0.68008, Accuracy: 26.7557%
# Std_dev:0.4------  Train__[4/5][3/12] Loss: 3.92494, BER: 0.66990, Accuracy: 27.2290%
# Std_dev:0.4------  Train__[4/5][4/12] Loss: 4.01394, BER: 0.66293, Accuracy: 26.4260%
# Std_dev:0.4------  Train__[4/5][5/12] Loss: 3.94436, BER: 0.65920, Accuracy: 27.1297%
# Std_dev:0.4------  Train__[4/5][6/12] Loss: 3.97159, BER: 0.65243, Accuracy: 26.8956%
# Std_dev:0.4------  Train__[4/5][7/12] Loss: 3.93731, BER: 0.65024, Accuracy: 27.1442%
# Std_dev:0.4------  Train__[4/5][8/12] Loss: 3.93854, BER: 0.64804, Accuracy: 27.3039%
# Std_dev:0.4------  Train__[4/5][9/12] Loss: 3.88984, BER: 0.64213, Accuracy: 27.6784%
# Std_dev:0.4------  Train__[4/5][10/12] Loss: 3.79819, BER: 0.64146, Accuracy: 28.4898%
# Std_dev:0.4------  Train__[4/5][11/12] Loss: 3.87646, BER: 0.61356, Accuracy: 27.9848%
# ----------------Epoch4/5 Train set ---------------
# Std_dev:0.4---- Epoch [4/5] Average loss (epoch): 3.92288, Average Accuracy (epoch): 27.2617%
# -------------------------------------
# Std_dev:0.4--- Test[4/5][0/12]  Loss(test): 1.97977, BER (test): 0.31876,  Accuracy(test): 47.4177%
# Std_dev:0.4--- Test[4/5][1/12]  Loss(test): 1.95385, BER (test): 0.31198,  Accuracy(test): 47.7186%
# Std_dev:0.4--- Test[4/5][2/12]  Loss(test): 1.90344, BER (test): 0.30295,  Accuracy(test): 48.2513%
# Std_dev:0.4--- Test[4/5][3/12]  Loss(test): 2.00859, BER (test): 0.32329,  Accuracy(test): 47.0999%
# Std_dev:0.4--- Test[4/5][4/12]  Loss(test): 1.89011, BER (test): 0.30266,  Accuracy(test): 48.3911%
# Std_dev:0.4--- Test[4/5][5/12]  Loss(test): 1.94501, BER (test): 0.31407,  Accuracy(test): 47.8035%
# Std_dev:0.4--- Test[4/5][6/12]  Loss(test): 1.98287, BER (test): 0.31898,  Accuracy(test): 47.3894%
# Std_dev:0.4--- Test[4/5][7/12]  Loss(test): 1.95184, BER (test): 0.30995,  Accuracy(test): 47.7445%
# Std_dev:0.4--- Test[4/5][8/12]  Loss(test): 1.88194, BER (test): 0.30327,  Accuracy(test): 48.4036%
# Std_dev:0.4--- Test[4/5][9/12]  Loss(test): 1.98493, BER (test): 0.32544,  Accuracy(test): 47.3215%
# Std_dev:0.4--- Test[4/5][10/12]  Loss(test): 1.91660, BER (test): 0.30829,  Accuracy(test): 47.9995%
# Std_dev:0.4--- Test[4/5][11/12]  Loss(test): 1.91577, BER (test): 0.30999,  Accuracy(test): 48.1584%
# ----------------Epoch4/5 Test set ---------------
# Std_dev:0.4------Epoch [4/5] Average loss_test (epoch): 1.94289, Average Accuracy_test (epoch): 47.8083%
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
#
# std_dev=0.4, mean=1.0, train_loss= 3.8765, test_loss= 1.9158, train_accuracy= 27.9848%, test_accuracy= 48.1584%
# ---------------------------------------------------------------------------------------
#
#
# --------------------------------------This shows the <std_dev> and <mean> have been changed --------------------------------------
#
# Std_dev:0.5------  Train__[0/5][0/12] Loss: 1.85777, BER: 0.24879, Accuracy: 52.3321%
# Std_dev:0.5------  Train__[0/5][1/12] Loss: 1.85132, BER: 0.24694, Accuracy: 52.4177%
# Std_dev:0.5------  Train__[0/5][2/12] Loss: 1.86171, BER: 0.24861, Accuracy: 52.2827%
# Std_dev:0.5------  Train__[0/5][3/12] Loss: 1.83562, BER: 0.24486, Accuracy: 52.6134%
# Std_dev:0.5------  Train__[0/5][4/12] Loss: 1.85162, BER: 0.24624, Accuracy: 52.4774%
# Std_dev:0.5------  Train__[0/5][5/12] Loss: 1.83819, BER: 0.24575, Accuracy: 52.5997%
# Std_dev:0.5------  Train__[0/5][6/12] Loss: 1.85012, BER: 0.24614, Accuracy: 52.4523%
# Std_dev:0.5------  Train__[0/5][7/12] Loss: 1.86414, BER: 0.24822, Accuracy: 52.3100%
# Std_dev:0.5------  Train__[0/5][8/12] Loss: 1.85448, BER: 0.24671, Accuracy: 52.4099%
# Std_dev:0.5------  Train__[0/5][9/12] Loss: 1.83914, BER: 0.24630, Accuracy: 52.5624%
# Std_dev:0.5------  Train__[0/5][10/12] Loss: 1.85289, BER: 0.24746, Accuracy: 52.4467%
# Std_dev:0.5------  Train__[0/5][11/12] Loss: 1.84891, BER: 0.24630, Accuracy: 52.4757%
# ----------------Epoch0/5 Train set ---------------
# Std_dev:0.5---- Epoch [0/5] Average loss (epoch): 1.85049, Average Accuracy (epoch): 52.4483%
# -------------------------------------
# Std_dev:0.5--- Test[0/5][0/12]  Loss(test): 0.60176, BER (test): 0.13004,  Accuracy(test): 80.9552%
# Std_dev:0.5--- Test[0/5][1/12]  Loss(test): 0.59472, BER (test): 0.12868,  Accuracy(test): 81.0706%
# Std_dev:0.5--- Test[0/5][2/12]  Loss(test): 0.59388, BER (test): 0.12835,  Accuracy(test): 81.1064%
# Std_dev:0.5--- Test[0/5][3/12]  Loss(test): 0.60753, BER (test): 0.13109,  Accuracy(test): 80.7870%
# Std_dev:0.5--- Test[0/5][4/12]  Loss(test): 0.60229, BER (test): 0.12983,  Accuracy(test): 80.9444%
# Std_dev:0.5--- Test[0/5][5/12]  Loss(test): 0.60938, BER (test): 0.13126,  Accuracy(test): 80.7713%
# Std_dev:0.5--- Test[0/5][6/12]  Loss(test): 0.60750, BER (test): 0.13167,  Accuracy(test): 80.8128%
# Std_dev:0.5--- Test[0/5][7/12]  Loss(test): 0.59302, BER (test): 0.12819,  Accuracy(test): 81.1116%
# Std_dev:0.5--- Test[0/5][8/12]  Loss(test): 0.61910, BER (test): 0.13277,  Accuracy(test): 80.6653%
# Std_dev:0.5--- Test[0/5][9/12]  Loss(test): 0.63732, BER (test): 0.13763,  Accuracy(test): 80.2463%
# Std_dev:0.5--- Test[0/5][10/12]  Loss(test): 0.60687, BER (test): 0.13050,  Accuracy(test): 80.9157%
# Std_dev:0.5--- Test[0/5][11/12]  Loss(test): 0.61924, BER (test): 0.13420,  Accuracy(test): 80.5785%
# ----------------Epoch0/5 Test set ---------------
# Std_dev:0.5------Epoch [0/5] Average loss_test (epoch): 0.60772, Average Accuracy_test (epoch): 80.8304%
# -----------------------------------------------------------------------------------------
# Std_dev:0.5------  Train__[1/5][0/12] Loss: 1.93750, BER: 0.25122, Accuracy: 51.6612%
# Std_dev:0.5------  Train__[1/5][1/12] Loss: 2.06869, BER: 0.25718, Accuracy: 50.3584%
# Std_dev:0.5------  Train__[1/5][2/12] Loss: 2.20422, BER: 0.26316, Accuracy: 48.9691%
# Std_dev:0.5------  Train__[1/5][3/12] Loss: 2.45659, BER: 0.27885, Accuracy: 46.3473%
# Std_dev:0.5------  Train__[1/5][4/12] Loss: 2.57405, BER: 0.28321, Accuracy: 45.1073%
# Std_dev:0.5------  Train__[1/5][5/12] Loss: 2.53279, BER: 0.28117, Accuracy: 45.4083%
# Std_dev:0.5------  Train__[1/5][6/12] Loss: 2.46904, BER: 0.27949, Accuracy: 46.0417%
# Std_dev:0.5------  Train__[1/5][7/12] Loss: 2.46834, BER: 0.28150, Accuracy: 45.9342%
# Std_dev:0.5------  Train__[1/5][8/12] Loss: 2.39730, BER: 0.28111, Accuracy: 46.6060%
# Std_dev:0.5------  Train__[1/5][9/12] Loss: 2.30772, BER: 0.27851, Accuracy: 47.4601%
# Std_dev:0.5------  Train__[1/5][10/12] Loss: 2.23084, BER: 0.27460, Accuracy: 48.3193%
# Std_dev:0.5------  Train__[1/5][11/12] Loss: 2.17208, BER: 0.26964, Accuracy: 48.9204%
# ----------------Epoch1/5 Train set ---------------
# Std_dev:0.5---- Epoch [1/5] Average loss (epoch): 2.31826, Average Accuracy (epoch): 47.5944%
# -------------------------------------
# Std_dev:0.5--- Test[1/5][0/12]  Loss(test): 0.59315, BER (test): 0.13004,  Accuracy(test): 81.4130%
# Std_dev:0.5--- Test[1/5][1/12]  Loss(test): 0.58616, BER (test): 0.12868,  Accuracy(test): 81.5283%
# Std_dev:0.5--- Test[1/5][2/12]  Loss(test): 0.58533, BER (test): 0.12835,  Accuracy(test): 81.5641%
# Std_dev:0.5--- Test[1/5][3/12]  Loss(test): 0.60305, BER (test): 0.13139,  Accuracy(test): 81.1804%
# Std_dev:0.5--- Test[1/5][4/12]  Loss(test): 0.59367, BER (test): 0.12983,  Accuracy(test): 81.4021%
# Std_dev:0.5--- Test[1/5][5/12]  Loss(test): 0.60154, BER (test): 0.13136,  Accuracy(test): 81.2124%
# Std_dev:0.5--- Test[1/5][6/12]  Loss(test): 0.59882, BER (test): 0.13167,  Accuracy(test): 81.2705%
# Std_dev:0.5--- Test[1/5][7/12]  Loss(test): 0.58448, BER (test): 0.12819,  Accuracy(test): 81.5694%
# Std_dev:0.5--- Test[1/5][8/12]  Loss(test): 0.61035, BER (test): 0.13277,  Accuracy(test): 81.1231%
# Std_dev:0.5--- Test[1/5][9/12]  Loss(test): 0.62838, BER (test): 0.13763,  Accuracy(test): 80.7040%
# Std_dev:0.5--- Test[1/5][10/12]  Loss(test): 0.59918, BER (test): 0.13062,  Accuracy(test): 81.3546%
# Std_dev:0.5--- Test[1/5][11/12]  Loss(test): 0.61046, BER (test): 0.13420,  Accuracy(test): 81.0363%
# ----------------Epoch1/5 Test set ---------------
# Std_dev:0.5------Epoch [1/5] Average loss_test (epoch): 0.59955, Average Accuracy_test (epoch): 81.2798%
# -----------------------------------------------------------------------------------------
# Std_dev:0.5------  Train__[2/5][0/12] Loss: 2.11013, BER: 0.26476, Accuracy: 49.6169%
# Std_dev:0.5------  Train__[2/5][1/12] Loss: 2.10880, BER: 0.26604, Accuracy: 49.5909%
# Std_dev:0.5------  Train__[2/5][2/12] Loss: 2.07930, BER: 0.26343, Accuracy: 50.0002%
# Std_dev:0.5------  Train__[2/5][3/12] Loss: 2.05538, BER: 0.26108, Accuracy: 50.2111%
# Std_dev:0.5------  Train__[2/5][4/12] Loss: 2.10272, BER: 0.26641, Accuracy: 49.6696%
# Std_dev:0.5------  Train__[2/5][5/12] Loss: 2.17313, BER: 0.27257, Accuracy: 48.7955%
# Std_dev:0.5------  Train__[2/5][6/12] Loss: 2.15943, BER: 0.26864, Accuracy: 49.0548%
# Std_dev:0.5------  Train__[2/5][7/12] Loss: 2.23023, BER: 0.27540, Accuracy: 48.1710%
# Std_dev:0.5------  Train__[2/5][8/12] Loss: 2.23745, BER: 0.27295, Accuracy: 48.1535%
# Std_dev:0.5------  Train__[2/5][9/12] Loss: 2.26545, BER: 0.27670, Accuracy: 47.7707%
# Std_dev:0.5------  Train__[2/5][10/12] Loss: 2.20430, BER: 0.27434, Accuracy: 48.3813%
# Std_dev:0.5------  Train__[2/5][11/12] Loss: 2.24380, BER: 0.27361, Accuracy: 48.0308%
# ----------------Epoch2/5 Train set ---------------
# Std_dev:0.5---- Epoch [2/5] Average loss (epoch): 2.16418, Average Accuracy (epoch): 48.9539%
# -------------------------------------
# Std_dev:0.5--- Test[2/5][0/12]  Loss(test): 0.58489, BER (test): 0.13004,  Accuracy(test): 81.8628%
# Std_dev:0.5--- Test[2/5][1/12]  Loss(test): 0.57917, BER (test): 0.12859,  Accuracy(test): 81.9729%
# Std_dev:0.5--- Test[2/5][2/12]  Loss(test): 0.57896, BER (test): 0.12839,  Accuracy(test): 81.9868%
# Std_dev:0.5--- Test[2/5][3/12]  Loss(test): 0.59557, BER (test): 0.13126,  Accuracy(test): 81.6334%
# Std_dev:0.5--- Test[2/5][4/12]  Loss(test): 0.58541, BER (test): 0.12983,  Accuracy(test): 81.8520%
# Std_dev:0.5--- Test[2/5][5/12]  Loss(test): 0.59383, BER (test): 0.13132,  Accuracy(test): 81.6623%
# Std_dev:0.5--- Test[2/5][6/12]  Loss(test): 0.59319, BER (test): 0.13169,  Accuracy(test): 81.6938%
# Std_dev:0.5--- Test[2/5][7/12]  Loss(test): 0.57728, BER (test): 0.12811,  Accuracy(test): 82.0142%
# Std_dev:0.5--- Test[2/5][8/12]  Loss(test): 0.60196, BER (test): 0.13277,  Accuracy(test): 81.5730%
# Std_dev:0.5--- Test[2/5][9/12]  Loss(test): 0.61980, BER (test): 0.13763,  Accuracy(test): 81.1539%
# Std_dev:0.5--- Test[2/5][10/12]  Loss(test): 0.58996, BER (test): 0.13050,  Accuracy(test): 81.8233%
# Std_dev:0.5--- Test[2/5][11/12]  Loss(test): 0.60203, BER (test): 0.13420,  Accuracy(test): 81.4862%
# ----------------Epoch2/5 Test set ---------------
# Std_dev:0.5------Epoch [2/5] Average loss_test (epoch): 0.59184, Average Accuracy_test (epoch): 81.7262%
# -----------------------------------------------------------------------------------------
# Std_dev:0.5------  Train__[3/5][0/12] Loss: 2.23351, BER: 0.27502, Accuracy: 47.9711%
# Std_dev:0.5------  Train__[3/5][1/12] Loss: 2.14582, BER: 0.27291, Accuracy: 48.9394%
# Std_dev:0.5------  Train__[3/5][2/12] Loss: 2.20619, BER: 0.27446, Accuracy: 48.3511%
# Std_dev:0.5------  Train__[3/5][3/12] Loss: 2.21985, BER: 0.27324, Accuracy: 48.1819%
# Std_dev:0.5------  Train__[3/5][4/12] Loss: 2.20250, BER: 0.27181, Accuracy: 48.3525%
# Std_dev:0.5------  Train__[3/5][5/12] Loss: 2.19071, BER: 0.27241, Accuracy: 48.4788%
# Std_dev:0.5------  Train__[3/5][6/12] Loss: 2.16652, BER: 0.27180, Accuracy: 48.7033%
# Std_dev:0.5------  Train__[3/5][7/12] Loss: 2.15943, BER: 0.27193, Accuracy: 48.8211%
# Std_dev:0.5------  Train__[3/5][8/12] Loss: 2.11661, BER: 0.26739, Accuracy: 49.2816%
# Std_dev:0.5------  Train__[3/5][9/12] Loss: 2.16966, BER: 0.27411, Accuracy: 48.6379%
# Std_dev:0.5------  Train__[3/5][10/12] Loss: 2.18939, BER: 0.27536, Accuracy: 48.4083%
# Std_dev:0.5------  Train__[3/5][11/12] Loss: 2.18123, BER: 0.27409, Accuracy: 48.5160%
# ----------------Epoch3/5 Train set ---------------
# Std_dev:0.5---- Epoch [3/5] Average loss (epoch): 2.18179, Average Accuracy (epoch): 48.5536%
# -------------------------------------
# Std_dev:0.5--- Test[3/5][0/12]  Loss(test): 0.57735, BER (test): 0.13007,  Accuracy(test): 82.2997%
# Std_dev:0.5--- Test[3/5][1/12]  Loss(test): 0.57251, BER (test): 0.12886,  Accuracy(test): 82.3788%
# Std_dev:0.5--- Test[3/5][2/12]  Loss(test): 0.56997, BER (test): 0.12843,  Accuracy(test): 82.4452%
# Std_dev:0.5--- Test[3/5][3/12]  Loss(test): 0.58321, BER (test): 0.13114,  Accuracy(test): 82.1272%
# Std_dev:0.5--- Test[3/5][4/12]  Loss(test): 0.57798, BER (test): 0.12986,  Accuracy(test): 82.2879%
# Std_dev:0.5--- Test[3/5][5/12]  Loss(test): 0.58517, BER (test): 0.13140,  Accuracy(test): 82.1051%
# Std_dev:0.5--- Test[3/5][6/12]  Loss(test): 0.58240, BER (test): 0.13167,  Accuracy(test): 82.1687%
# Std_dev:0.5--- Test[3/5][7/12]  Loss(test): 0.56833, BER (test): 0.12819,  Accuracy(test): 82.4676%
# Std_dev:0.5--- Test[3/5][8/12]  Loss(test): 0.59459, BER (test): 0.13287,  Accuracy(test): 82.0033%
# Std_dev:0.5--- Test[3/5][9/12]  Loss(test): 0.61145, BER (test): 0.13763,  Accuracy(test): 81.6022%
# Std_dev:0.5--- Test[3/5][10/12]  Loss(test): 0.58320, BER (test): 0.13060,  Accuracy(test): 82.2434%
# Std_dev:0.5--- Test[3/5][11/12]  Loss(test): 0.59383, BER (test): 0.13420,  Accuracy(test): 81.9345%
# ----------------Epoch3/5 Test set ---------------
# Std_dev:0.5------Epoch [3/5] Average loss_test (epoch): 0.58333, Average Accuracy_test (epoch): 82.1720%
# -----------------------------------------------------------------------------------------
# Std_dev:0.5------  Train__[4/5][0/12] Loss: 2.25877, BER: 0.27968, Accuracy: 47.5836%
# Std_dev:0.5------  Train__[4/5][1/12] Loss: 2.27242, BER: 0.27627, Accuracy: 47.4844%
# Std_dev:0.5------  Train__[4/5][2/12] Loss: 2.29341, BER: 0.28050, Accuracy: 47.1977%
# Std_dev:0.5------  Train__[4/5][3/12] Loss: 2.29256, BER: 0.28089, Accuracy: 47.2381%
# Std_dev:0.5------  Train__[4/5][4/12] Loss: 2.32561, BER: 0.28409, Accuracy: 46.7751%
# Std_dev:0.5------  Train__[4/5][5/12] Loss: 2.22901, BER: 0.27616, Accuracy: 47.8615%
# Std_dev:0.5------  Train__[4/5][6/12] Loss: 2.21883, BER: 0.28028, Accuracy: 47.9892%
# Std_dev:0.5------  Train__[4/5][7/12] Loss: 2.14072, BER: 0.27202, Accuracy: 48.8392%
# Std_dev:0.5------  Train__[4/5][8/12] Loss: 2.18230, BER: 0.27625, Accuracy: 48.3423%
# Std_dev:0.5------  Train__[4/5][9/12] Loss: 2.21313, BER: 0.27989, Accuracy: 47.9519%
# Std_dev:0.5------  Train__[4/5][10/12] Loss: 2.18579, BER: 0.27699, Accuracy: 48.3012%
# Std_dev:0.5------  Train__[4/5][11/12] Loss: 2.17800, BER: 0.27748, Accuracy: 48.3560%
# ----------------Epoch4/5 Train set ---------------
# ...
# -------------------------------------
# Std_dev:0.9--- Test[4/5][0/12]  Loss(test): 1.78072, BER (test): 0.14452,  Accuracy(test): 48.5416%
# Std_dev:0.9--- Test[4/5][1/12]  Loss(test): 1.76211, BER (test): 0.14258,  Accuracy(test): 48.7268%
# Std_dev:0.9--- Test[4/5][2/12]  Loss(test): 1.78574, BER (test): 0.14626,  Accuracy(test): 48.5728%
# Std_dev:0.9--- Test[4/5][3/12]  Loss(test): 1.80167, BER (test): 0.14777,  Accuracy(test): 48.2710%
# Std_dev:0.9--- Test[4/5][4/12]  Loss(test): 1.79622, BER (test): 0.14342,  Accuracy(test): 48.2607%
# Std_dev:0.9--- Test[4/5][5/12]  Loss(test): 1.81055, BER (test): 0.14567,  Accuracy(test): 48.0732%
# Std_dev:0.9--- Test[4/5][6/12]  Loss(test): 1.79933, BER (test): 0.14761,  Accuracy(test): 48.3052%
# Std_dev:0.9--- Test[4/5][7/12]  Loss(test): 1.77293, BER (test): 0.14546,  Accuracy(test): 48.7115%
# Std_dev:0.9--- Test[4/5][8/12]  Loss(test): 1.81254, BER (test): 0.14704,  Accuracy(test): 48.1429%
# Std_dev:0.9--- Test[4/5][9/12]  Loss(test): 1.83395, BER (test): 0.14937,  Accuracy(test): 47.7766%
# Std_dev:0.9--- Test[4/5][10/12]  Loss(test): 1.78759, BER (test): 0.14589,  Accuracy(test): 48.4768%
# Std_dev:0.9--- Test[4/5][11/12]  Loss(test): 1.80628, BER (test): 0.14732,  Accuracy(test): 48.1392%
# ----------------Epoch4/5 Test set ---------------
# Std_dev:0.9------Epoch [4/5] Average loss_test (epoch): 1.79580, Average Accuracy_test (epoch): 48.3332%
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
#
# std_dev=0.9, mean=0.6000000000000001, train_loss= 10.2244, test_loss= 1.8063, train_accuracy= -18.0883%, test_accuracy= 48.1392%
# ---------------------------------------------------------------------------------------
#
#
# --------------------------------------This shows the <std_dev> and <mean> have been changed --------------------------------------
#
# Std_dev:0.9------  Train__[0/5][0/12] Loss: 25.45164, BER: 0.67432, Accuracy: -105.8152%
# Std_dev:0.9------  Train__[0/5][1/12] Loss: 25.43022, BER: 0.67301, Accuracy: -105.5920%
# Std_dev:0.9------  Train__[0/5][2/12] Loss: 25.45702, BER: 0.67406, Accuracy: -105.7630%
# Std_dev:0.9------  Train__[0/5][3/12] Loss: 25.27774, BER: 0.67183, Accuracy: -104.9495%
# Std_dev:0.9------  Train__[0/5][4/12] Loss: 25.42942, BER: 0.67419, Accuracy: -105.6177%
# Std_dev:0.9------  Train__[0/5][5/12] Loss: 25.32535, BER: 0.67330, Accuracy: -105.2399%
# Std_dev:0.9------  Train__[0/5][6/12] Loss: 25.29349, BER: 0.67109, Accuracy: -104.9065%
# Std_dev:0.9------  Train__[0/5][7/12] Loss: 25.32085, BER: 0.67279, Accuracy: -105.1235%
# Std_dev:0.9------  Train__[0/5][8/12] Loss: 25.42170, BER: 0.67390, Accuracy: -105.5396%
# Std_dev:0.9------  Train__[0/5][9/12] Loss: 25.35942, BER: 0.67363, Accuracy: -105.2940%
# Std_dev:0.9------  Train__[0/5][10/12] Loss: 25.37502, BER: 0.67332, Accuracy: -105.3749%
# Std_dev:0.9------  Train__[0/5][11/12] Loss: 25.31757, BER: 0.67469, Accuracy: -105.2204%
# ----------------Epoch0/5 Train set ---------------
# Std_dev:0.9---- Epoch [0/5] Average loss (epoch): 25.37162, Average Accuracy (epoch): -105.3697%
# -------------------------------------
# Std_dev:0.9--- Test[0/5][0/12]  Loss(test): 8.13952, BER (test): 0.13012,  Accuracy(test): -24.2109%
# Std_dev:0.9--- Test[0/5][1/12]  Loss(test): 8.12189, BER (test): 0.12888,  Accuracy(test): -24.0606%
# Std_dev:0.9--- Test[0/5][2/12]  Loss(test): 8.11727, BER (test): 0.12842,  Accuracy(test): -24.0606%
# Std_dev:0.9--- Test[0/5][3/12]  Loss(test): 8.16383, BER (test): 0.13131,  Accuracy(test): -24.3368%
# Std_dev:0.9--- Test[0/5][4/12]  Loss(test): 8.14325, BER (test): 0.13003,  Accuracy(test): -24.1580%
# Std_dev:0.9--- Test[0/5][5/12]  Loss(test): 8.16693, BER (test): 0.13139,  Accuracy(test): -24.3843%
# Std_dev:0.9--- Test[0/5][6/12]  Loss(test): 8.16051, BER (test): 0.13180,  Accuracy(test): -24.2918%
# Std_dev:0.9--- Test[0/5][7/12]  Loss(test): 8.11401, BER (test): 0.12825,  Accuracy(test): -24.0391%
# Std_dev:0.9--- Test[0/5][8/12]  Loss(test): 8.18832, BER (test): 0.13295,  Accuracy(test): -24.4372%
# Std_dev:0.9--- Test[0/5][9/12]  Loss(test): 8.25281, BER (test): 0.13795,  Accuracy(test): -24.8468%
# Std_dev:0.9--- Test[0/5][10/12]  Loss(test): 8.14901, BER (test): 0.13057,  Accuracy(test): -24.2072%
# Std_dev:0.9--- Test[0/5][11/12]  Loss(test): 8.19718, BER (test): 0.13429,  Accuracy(test): -24.5803%
# ----------------Epoch0/5 Test set ---------------
# Std_dev:0.9------Epoch [0/5] Average loss_test (epoch): 8.15954, Average Accuracy_test (epoch): -24.3011%
# -----------------------------------------------------------------------------------------
# Std_dev:0.9------  Train__[1/5][0/12] Loss: 25.28318, BER: 0.67421, Accuracy: -105.0230%
# Std_dev:0.9------  Train__[1/5][1/12] Loss: 25.04619, BER: 0.66902, Accuracy: -103.5104%
# Std_dev:0.9------  Train__[1/5][2/12] Loss: 25.29051, BER: 0.67180, Accuracy: -103.6503%
# Std_dev:0.9------  Train__[1/5][3/12] Loss: 25.25065, BER: 0.66942, Accuracy: -102.2823%
# Std_dev:0.9------  Train__[1/5][4/12] Loss: 25.24166, BER: 0.67028, Accuracy: -101.9794%
# Std_dev:0.9------  Train__[1/5][5/12] Loss: 25.17228, BER: 0.66963, Accuracy: -101.0865%
# Std_dev:0.9------  Train__[1/5][6/12] Loss: 25.17713, BER: 0.66905, Accuracy: -101.0047%
# Std_dev:0.9------  Train__[1/5][7/12] Loss: 25.09204, BER: 0.66980, Accuracy: -100.8605%
# Std_dev:0.9------  Train__[1/5][8/12] Loss: 24.94693, BER: 0.66988, Accuracy: -100.1230%
# Std_dev:0.9------  Train__[1/5][9/12] Loss: 25.03679, BER: 0.67005, Accuracy: -100.7216%
# Std_dev:0.9------  Train__[1/5][10/12] Loss: 24.88763, BER: 0.66904, Accuracy: -100.7176%
# Std_dev:0.9------  Train__[1/5][11/12] Loss: 24.83313, BER: 0.67076, Accuracy: -100.3989%
# ----------------Epoch1/5 Train set ---------------
# Std_dev:0.9---- Epoch [1/5] Average loss (epoch): 25.10484, Average Accuracy (epoch): -101.7799%
# -------------------------------------
# Std_dev:0.9--- Test[1/5][0/12]  Loss(test): 8.08467, BER (test): 0.13447,  Accuracy(test): -21.4451%
# Std_dev:0.9--- Test[1/5][1/12]  Loss(test): 8.06911, BER (test): 0.13371,  Accuracy(test): -21.0752%
# Std_dev:0.9--- Test[1/5][2/12]  Loss(test): 8.06467, BER (test): 0.13226,  Accuracy(test): -21.5110%
# Std_dev:0.9--- Test[1/5][3/12]  Loss(test): 8.10983, BER (test): 0.13599,  Accuracy(test): -21.3837%
# Std_dev:0.9--- Test[1/5][4/12]  Loss(test): 8.09218, BER (test): 0.13378,  Accuracy(test): -21.7611%
# Std_dev:0.9--- Test[1/5][5/12]  Loss(test): 8.12859, BER (test): 0.13612,  Accuracy(test): -21.5748%
# Std_dev:0.9--- Test[1/5][6/12]  Loss(test): 8.10561, BER (test): 0.13639,  Accuracy(test): -21.3335%
# Std_dev:0.9--- Test[1/5][7/12]  Loss(test): 8.06485, BER (test): 0.13293,  Accuracy(test): -21.2047%
# Std_dev:0.9--- Test[1/5][8/12]  Loss(test): 8.12623, BER (test): 0.13683,  Accuracy(test): -21.8715%
# Std_dev:0.9--- Test[1/5][9/12]  Loss(test): 8.20636, BER (test): 0.14162,  Accuracy(test): -22.4121%
# Std_dev:0.9--- Test[1/5][10/12]  Loss(test): 8.11636, BER (test): 0.13503,  Accuracy(test): -21.6883%
# Std_dev:0.9--- Test[1/5][11/12]  Loss(test): 8.14471, BER (test): 0.13834,  Accuracy(test): -22.0364%
# ----------------Epoch1/5 Test set ---------------
# Std_dev:0.9------Epoch [1/5] Average loss_test (epoch): 8.10943, Average Accuracy_test (epoch): -21.6081%
# -----------------------------------------------------------------------------------------
# Std_dev:0.9------  Train__[2/5][0/12] Loss: 24.71047, BER: 0.66882, Accuracy: -99.6055%
# Std_dev:0.9------  Train__[2/5][1/12] Loss: 24.75731, BER: 0.67024, Accuracy: -99.8711%
# Std_dev:0.9------  Train__[2/5][2/12] Loss: 24.71118, BER: 0.67004, Accuracy: -99.8987%
# Std_dev:0.9------  Train__[2/5][3/12] Loss: 24.56113, BER: 0.67027, Accuracy: -98.8808%
# Std_dev:0.9------  Train__[2/5][4/12] Loss: 24.56047, BER: 0.67127, Accuracy: -99.0478%
# Std_dev:0.9------  Train__[2/5][5/12] Loss: 24.59019, BER: 0.67021, Accuracy: -99.4842%
# Std_dev:0.9------  Train__[2/5][6/12] Loss: 24.62002, BER: 0.67130, Accuracy: -99.6440%
# Std_dev:0.9------  Train__[2/5][7/12] Loss: 24.49145, BER: 0.67044, Accuracy: -99.2820%
# Std_dev:0.9------  Train__[2/5][8/12] Loss: 24.47144, BER: 0.66974, Accuracy: -99.1959%
# Std_dev:0.9------  Train__[2/5][9/12] Loss: 24.30100, BER: 0.67005, Accuracy: -98.3425%
# Std_dev:0.9------  Train__[2/5][10/12] Loss: 24.29530, BER: 0.67020, Accuracy: -98.0904%
# Std_dev:0.9------  Train__[2/5][11/12] Loss: 24.19597, BER: 0.66963, Accuracy: -97.5400%
# ----------------Epoch2/5 Train set ---------------
# Std_dev:0.9---- Epoch [2/5] Average loss (epoch): 24.52216, Average Accuracy (epoch): -99.0736%
# -------------------------------------
# Std_dev:0.9--- Test[2/5][0/12]  Loss(test): 7.85225, BER (test): 0.13911,  Accuracy(test): -18.5163%
# Std_dev:0.9--- Test[2/5][1/12]  Loss(test): 7.84441, BER (test): 0.13804,  Accuracy(test): -18.5342%
# Std_dev:0.9--- Test[2/5][2/12]  Loss(test): 7.86484, BER (test): 0.13735,  Accuracy(test): -18.8509%
# Std_dev:0.9--- Test[2/5][3/12]  Loss(test): 7.88946, BER (test): 0.13994,  Accuracy(test): -18.8571%
# Std_dev:0.9--- Test[2/5][4/12]  Loss(test): 7.88183, BER (test): 0.13859,  Accuracy(test): -19.0369%
# Std_dev:0.9--- Test[2/5][5/12]  Loss(test): 7.86305, BER (test): 0.14036,  Accuracy(test): -18.4975%
# Std_dev:0.9--- Test[2/5][6/12]  Loss(test): 7.89267, BER (test): 0.14107,  Accuracy(test): -18.9069%
# Std_dev:0.9--- Test[2/5][7/12]  Loss(test): 7.85357, BER (test): 0.13728,  Accuracy(test): -18.7702%
# Std_dev:0.9--- Test[2/5][8/12]  Loss(test): 7.88900, BER (test): 0.14180,  Accuracy(test): -18.7330%
# Std_dev:0.9--- Test[2/5][9/12]  Loss(test): 7.98425, BER (test): 0.14698,  Accuracy(test): -19.5501%
# Std_dev:0.9--- Test[2/5][10/12]  Loss(test): 7.89801, BER (test): 0.13926,  Accuracy(test): -19.1163%
# Std_dev:0.9--- Test[2/5][11/12]  Loss(test): 7.90440, BER (test): 0.14307,  Accuracy(test): -18.8256%
# ----------------Epoch2/5 Test set ---------------
# Std_dev:0.9------Epoch [2/5] Average loss_test (epoch): 7.88481, Average Accuracy_test (epoch): -18.8496%
# -----------------------------------------------------------------------------------------
# Std_dev:0.9------  Train__[3/5][0/12] Loss: 24.09533, BER: 0.66910, Accuracy: -96.8876%
# Std_dev:0.9------  Train__[3/5][1/12] Loss: 23.94721, BER: 0.66690, Accuracy: -95.7839%
# Std_dev:0.9------  Train__[3/5][2/12] Loss: 23.84006, BER: 0.66750, Accuracy: -95.1842%
# Std_dev:0.9------  Train__[3/5][3/12] Loss: 23.82343, BER: 0.66859, Accuracy: -94.6184%
# Std_dev:0.9------  Train__[3/5][4/12] Loss: 23.81318, BER: 0.66936, Accuracy: -94.3277%
# Std_dev:0.9------  Train__[3/5][5/12] Loss: 23.47513, BER: 0.66852, Accuracy: -92.4167%
# Std_dev:0.9------  Train__[3/5][6/12] Loss: 23.66656, BER: 0.66853, Accuracy: -92.7540%
# Std_dev:0.9------  Train__[3/5][7/12] Loss: 23.45255, BER: 0.66806, Accuracy: -91.6718%
# Std_dev:0.9------  Train__[3/5][8/12] Loss: 23.24513, BER: 0.66724, Accuracy: -90.6739%
# Std_dev:0.9------  Train__[3/5][9/12] Loss: 23.19608, BER: 0.66834, Accuracy: -90.3264%
# Std_dev:0.9------  Train__[3/5][10/12] Loss: 23.25289, BER: 0.66889, Accuracy: -90.3397%
# Std_dev:0.9------  Train__[3/5][11/12] Loss: 23.03840, BER: 0.66835, Accuracy: -89.1128%
# ----------------Epoch3/5 Train set ---------------
# Std_dev:0.9---- Epoch [3/5] Average loss (epoch): 23.57050, Average Accuracy (epoch): -92.8414%
# -------------------------------------
# Std_dev:0.9--- Test[3/5][0/12]  Loss(test): 6.66145, BER (test): 0.15964,  Accuracy(test): -1.6149%
# Std_dev:0.9--- Test[3/5][1/12]  Loss(test): 6.63821, BER (test): 0.16227,  Accuracy(test): -0.9441%
# Std_dev:0.9--- Test[3/5][2/12]  Loss(test): 6.68600, BER (test): 0.16128,  Accuracy(test): -1.7873%
# Std_dev:0.9--- Test[3/5][3/12]  Loss(test): 6.65818, BER (test): 0.16391,  Accuracy(test): -1.3035%
# Std_dev:0.9--- Test[3/5][4/12]  Loss(test): 6.66240, BER (test): 0.16221,  Accuracy(test): -1.3842%
# Std_dev:0.9--- Test[3/5][5/12]  Loss(test): 6.67661, BER (test): 0.16433,  Accuracy(test): -1.5290%
# Std_dev:0.9--- Test[3/5][6/12]  Loss(test): 6.64128, BER (test): 0.16447,  Accuracy(test): -1.0552%
# Std_dev:0.9--- Test[3/5][7/12]  Loss(test): 6.61188, BER (test): 0.15920,  Accuracy(test): -1.1426%
# Std_dev:0.9--- Test[3/5][8/12]  Loss(test): 6.64960, BER (test): 0.16540,  Accuracy(test): -0.9843%
# Std_dev:0.9--- Test[3/5][9/12]  Loss(test): 6.68889, BER (test): 0.16932,  Accuracy(test): -1.4266%
# Std_dev:0.9--- Test[3/5][10/12]  Loss(test): 6.67579, BER (test): 0.16337,  Accuracy(test): -1.4023%
# Std_dev:0.9--- Test[3/5][11/12]  Loss(test): 6.71996, BER (test): 0.16569,  Accuracy(test): -1.9941%
# ----------------Epoch3/5 Test set ---------------
# Std_dev:0.9------Epoch [3/5] Average loss_test (epoch): 6.66419, Average Accuracy_test (epoch): -1.3807%
# -----------------------------------------------------------------------------------------
# Std_dev:0.9------  Train__[4/5][0/12] Loss: 22.86536, BER: 0.66657, Accuracy: -88.2857%
# Std_dev:0.9------  Train__[4/5][1/12] Loss: 22.79151, BER: 0.66748, Accuracy: -87.7404%
# Std_dev:0.9------  Train__[4/5][2/12] Loss: 22.66332, BER: 0.66632, Accuracy: -87.1757%
# Std_dev:0.9------  Train__[4/5][3/12] Loss: 22.54596, BER: 0.66526, Accuracy: -86.3826%
# Std_dev:0.9------  Train__[4/5][4/12] Loss: 22.27169, BER: 0.66435, Accuracy: -84.8059%
# Std_dev:0.9------  Train__[4/5][5/12] Loss: 21.88968, BER: 0.66161, Accuracy: -82.8760%
# Std_dev:0.9------  Train__[4/5][6/12] Loss: 21.87704, BER: 0.66264, Accuracy: -82.9272%
# Std_dev:0.9------  Train__[4/5][7/12] Loss: 21.67892, BER: 0.66137, Accuracy: -81.7434%
# Std_dev:0.9------  Train__[4/5][8/12] Loss: 21.54677, BER: 0.66083, Accuracy: -81.0185%
# Std_dev:0.9------  Train__[4/5][9/12] Loss: 21.56176, BER: 0.66386, Accuracy: -80.8763%
# Std_dev:0.9------  Train__[4/5][10/12] Loss: 21.26830, BER: 0.66086, Accuracy: -79.3665%
# Std_dev:0.9------  Train__[4/5][11/12] Loss: 21.09013, BER: 0.65985, Accuracy: -78.2675%
# ----------------Epoch4/5 Train set ---------------
# Std_dev:0.9---- Epoch [4/5] Average loss (epoch): 22.00420, Average Accuracy (epoch): -83.4555%
# -------------------------------------
# Std_dev:0.9--- Test[4/5][0/12]  Loss(test): 5.47162, BER (test): 0.21076,  Accuracy(test): 13.7449%
# Std_dev:0.9--- Test[4/5][1/12]  Loss(test): 5.48529, BER (test): 0.20748,  Accuracy(test): 13.5300%
# Std_dev:0.9--- Test[4/5][2/12]  Loss(test): 5.49144, BER (test): 0.21112,  Accuracy(test): 13.4819%
# Std_dev:0.9--- Test[4/5][3/12]  Loss(test): 5.50996, BER (test): 0.21229,  Accuracy(test): 13.4047%
# Std_dev:0.9--- Test[4/5][4/12]  Loss(test): 5.49710, BER (test): 0.20877,  Accuracy(test): 13.3374%
# Std_dev:0.9--- Test[4/5][5/12]  Loss(test): 5.47138, BER (test): 0.21369,  Accuracy(test): 13.7805%
# Std_dev:0.9--- Test[4/5][6/12]  Loss(test): 5.48832, BER (test): 0.21457,  Accuracy(test): 13.6600%
# Std_dev:0.9--- Test[4/5][7/12]  Loss(test): 5.45744, BER (test): 0.20753,  Accuracy(test): 13.7138%
# Std_dev:0.9--- Test[4/5][8/12]  Loss(test): 5.52185, BER (test): 0.21347,  Accuracy(test): 13.3700%
# Std_dev:0.9--- Test[4/5][9/12]  Loss(test): 5.57027, BER (test): 0.21469,  Accuracy(test): 12.8384%
# Std_dev:0.9--- Test[4/5][10/12]  Loss(test): 5.49187, BER (test): 0.21164,  Accuracy(test): 13.6345%
# Std_dev:0.9--- Test[4/5][11/12]  Loss(test): 5.55084, BER (test): 0.21313,  Accuracy(test): 13.0401%
# ----------------Epoch4/5 Test set ---------------
# Std_dev:0.9------Epoch [4/5] Average loss_test (epoch): 5.50062, Average Accuracy_test (epoch): 13.4614%
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------
#
# std_dev=0.9, mean=0.8, train_loss= 21.0901, test_loss= 5.5508, train_accuracy= -78.2675%, test_accuracy= 13.0401%
# ---------------------------------------------------------------------------------------
#
#
# --------------------------------------This shows the <std_dev> and <mean> have been changed --------------------------------------
#
# Std_dev:0.9------  Train__[0/5][0/12] Loss: 7.41767, BER: 0.74739, Accuracy: 1.4045%

# %%
# import os

# # Define the range of std_dev values to explore
# stddev_num_intervals = 11  # Adjust the number of intervals as needed
# std_dev_range = np.linspace(0, 1, stddev_num_intervals)  # Generate values from 0 to 0.2 with stddev_num_intervals intervals
# mean = 0.5  # Define the mean value for the Gaussian noise


# best_std_dev = None
# best_loss = float('inf')
# best_accuracy = 0
# best_train_loss = float('inf')
# best_train_accuracy = 0
# # Lists to store metrics
# std_dev_values = []
# train_losses = []
# test_losses = []
# train_accuracies = []
# test_accuracies = []

# # Number of grid search iterations
# num_iterations = stddev_num_intervals  # One iteration per std_dev value

# for std_dev in std_dev_range:
#     # Reset network and optimizer for each std_dev value
#     net = SAE().to(device)
#     optimizer = torch.optim.AdamW(net.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=0.001)

#     # Create a folder to save intermediate layers for the current std_dev
#     intermediate_layers_dir = f"Intermediate_Lyrs/std_dev_{std_dev}"
#     os.makedirs(intermediate_layers_dir, exist_ok=True)
#     print('\n--------------------------------------This shows the std_dev has been changed --------------------------------------\n')

#     # Run training and testing
#     for e in range(epochs):
#         train_loss, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en = train(net, train_loader, optimizer, e, std_dev)
#         # train_avg_loss_rec.append(sum(train_loss_rec) / len(train_loader))

#         test_loss, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en = test(net, test_loader, optimizer, e, std_dev)
#         # print('-------------------')
#         # print('test_loss: ', test_loss)
#         # print('test_loss.item(): ', test_loss.item())
#         # print('test_accuracy[-1]: ', test_accuracy[-1])
#         # # print('epoch_loss_test: ', epoch_loss_test)
#         # # print('epoch_accuracy_test: ', epoch_accuracy_test)
#         # print('-------------------')

#         # Save intermediate layers every 10 epochs
#         if (e + 1) % 10 == 0:
#             activations_path = f"{intermediate_layers_dir}/activations_epoch_{e + 1}.pkl"
#             with open(activations_path, 'wb') as file:
#                 pickle.dump(epoch_activations, file)

#     # Evaluate performance with the current std_dev based on the last epoch
#     print('test_loss.item():', test_loss.item())
#     print('best_loss:',best_loss)
#     print('test_accuracy[-1]:', test_accuracy[-1])
#     print('best_accuracy:', best_accuracy)
#     # print('best_accuracy[-1]:', best_accuracy[-1])

#     # Record metrics
#     std_dev_values.append(std_dev)
#     train_losses.append(train_loss.item())
#     test_losses.append(test_loss.item())
#     train_accuracies.append(train_accuracy[-1])
#     test_accuracies.append(test_accuracy[-1])

#     if test_loss.item() < best_loss and test_accuracy[-1] > best_accuracy:
#       best_std_dev = std_dev
#       best_loss = test_loss.item()
#       best_accuracy = test_accuracy[-1]
#       best_train_loss = train_loss.item()
#       best_train_accuracy = train_accuracy[-1]

#     print('---------------------------------------------------------------------------------------\n')
#     # print(f"std_dev={std_dev}, train_loss= {train_loss:.4f}, test_loss= {test_loss:.4f}, train_accuracy= {train_accuracy:.4f}%, test_accuracy= {test_accuracy:.4f}%")
#     print(f"std_dev={std_dev}-------, train_loss= {train_loss.item():.4f} , test_loss= {test_loss.item():.4f}, train_accuracy= {train_accuracy[-1]*100:.4f}%, test_accuracy= {test_accuracy[-1]*100:.4f}%")
#     print('---------------------------------------------------------------------------------------\n')


# print('\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n')
# print(f"Best std_dev: {best_std_dev}, Best train_loss: {best_train_loss:.4f}, Best test_loss: {best_loss:.4f}, Best train_accuracy: {best_train_accuracy*100:.4f}%, Best test_accuracy: {best_accuracy*100:.4f}%")
# print('\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n')


# # ----------------------------------------------------------------------------------Plotting the results
# plt.figure(figsize=(12, 6))
# # fig, axs = plt.subplots(2, 1, figsize=(6, 12))
# font_size = 15
# font = {'weight': 'bold', 'size': 22}
# # Loss plot
# plt.subplot(1, 2, 1)
# plt.plot(std_dev_values, train_losses, label='Train Loss')
# plt.plot(std_dev_values, test_losses, label='Test Loss')
# plt.xlabel('std_dev', fontweight="bold", fontdict=font)
# plt.ylabel('Loss', fontweight="bold", fontdict=font)
# plt.title('Loss vs. std_dev', fontweight="bold", fontdict=font)
# plt.tick_params(labelsize=font_size)
# plt.legend(fontsize='large')

# # Accuracy plot
# plt.subplot(1, 2, 2)
# plt.plot(std_dev_values, train_accuracies, label='Train Accuracy')
# plt.plot(std_dev_values, test_accuracies, label='Test Accuracy')
# plt.xlabel('std_dev', fontweight="bold", fontdict=font)
# plt.ylabel('Accuracy (%)', fontweight="bold", fontdict=font)
# plt.title('Accuracy vs. std_dev', fontweight="bold", fontdict=font)
# plt.tick_params(labelsize=font_size)
# plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())  # Format y-axis as percentage
# plt.legend(fontsize='large')

# plt.tight_layout()
# plt.savefig('Loss&Acc_StdDev_GaussinaNoise_input.png', dpi=300)  # dpi controls the quality (dots per inch)

# plt.show()

# %%
print("Best std_dev: 0.046153846153846156, Best train_loss: 0.5006, Best test_loss: 0.4890, Best train_accuracy: 84.0904%, Best test_accuracy: 85.7873%")
print('std_dev=0.34177215189873417-------, train_loss= 1.3233 , test_loss= 0.4465, train_accuracy= 61.7785%, test_accuracy= 82.8034%')
print('std_dev=0.7215189873417721-------, train_loss= 3.6373 , test_loss= 0.4894, train_accuracy= 32.9415%, test_accuracy= 85.8028%')

# %% [markdown]
# ### Random Search

# %%
# # /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# import random

# # Define the range of std_dev values to explore
# stddev_num_intervals = 20  # Adjust the number of intervals as needed

# # Define the range of std_dev values to explore
# std_dev_range = np.linspace(0, 0.2, stddev_num_intervals)  # Generate values from 0 to 2 with stddev_num_intervals intervals


# best_std_dev = None
# best_loss = float('inf')
# best_accuracy = 0.0

# # Number of random search iterations
# num_iterations = 10  # Adjust as needed

# # # -----------------------------------------------
# for i in range(num_iterations):
#     # Sample a value for std_dev
#     std_dev = np.random.choice(std_dev_range)

#     # Update std_dev in your code
#     std_dev = std_dev

#     # Reset network and optimizer
#       #Define Network and optimizer
#     net=SAE()
#     net = net.to(device)
#     optimizer = torch.optim.AdamW(net.parameters(),
#                             lr=0.0001,
#                             betas=(0.9, 0.999),
#                             weight_decay=0.001)

#     # Create a folder to save intermediate layers for the current std_dev
#     intermediate_layers_dir = f"Intermediate_Lyrs/std_dev_{std_dev}"
#     os.makedirs(intermediate_layers_dir, exist_ok=True)

#     # Run training and testing
#     for e in range(epochs):
#         train_loss, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en = train(net, train_loader, optimizer, e)
#         train_avg_loss_rec.append(sum(train_loss_rec) / len(train_loader))

#         test_loss, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en = test(net, test_loader, optimizer, e)
#         test_avg_loss_rec.append(sum(test_loss_rec) / (len(test_loader)))

#         # Access activations and save them
#         epoch_activations[e] = {}
#         for i, name in enumerate(hook_names):
#             epoch_activations[e][name] = activation.get(name, None)  # Use get to avoid KeyError

#         # Save intermediate layers every 10 epochs
#         if (e + 1) % 10 == 0:
#             # activations_path = Intermediate_Lyrs + f"activations_epoch_{e + 1}.pkl"
#             activations_path = f"{intermediate_layers_dir}/activations_epoch_{e + 1}.pkl"
#             with open(activations_path, 'wb') as file:
#                 pickle.dump(epoch_activations, file)

#     # Evaluate performance with the current std_dev
#     avg_test_accuracy = np.mean(test_accuracy)  # Calculate average test accuracy over all epochs
#     if test_loss < best_loss and avg_test_accuracy > best_accuracy:
#         best_std_dev = std_dev
#         best_loss = test_loss
#         best_accuracy = avg_test_accuracy

#     print(f"Iteration {i + 1}: std_dev={std_dev}, test_loss={test_loss}, test_accuracy={avg_test_accuracy}")

# print(f"Best std_dev: {best_std_dev}, Best test_loss: {best_loss}, Best test_accuracy: {best_accuracy}")

# %%
# def train_and_evaluate(std_dev):
#     # Your training and evaluation code here
#     # Run training and testing
#     for e in range(epochs):
#         train_loss, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en = train(net, train_loader, optimizer, e, std_dev)
#         train_avg_loss_rec.append(sum(train_loss_rec) / len(train_loader))

#         test_loss, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en = test(net, test_loader, optimizer, e, std_dev)
#         test_avg_loss_rec.append(sum(test_loss_rec) / (len(test_loader)))

#         # Intermediate Layers
#         # Check if the current epoch is a multiple of 10
#         if (e + 1) % 10 == 0:
#             # Save the epoch_activations dictionary to a file
#             activations_path = Intermediate_Lyrs +  f"activations_epoch_{e + 1}.pkl"
#             with open(activations_path, 'wb') as file:
#                 pickle.dump(epoch_activations, file)

#         # Capture activations for the current epoch
#         epoch_activations[e] = {}
#         for i, name in enumerate(hook_names):
#             epoch_activations[e][name] = activation.get(name, None)  # Use get to avoid KeyError


#     # Update the std_dev parameter with the value provided by Bayesian Optimization
#     std_dev = std_dev

#     # Run training and testing with the updated std_dev
#     # Call the train and test functions with the updated std_dev
#     train_loss, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en = train(net, train_loader, optimizer, e, std_dev)
#     test_loss, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en = test(net, test_loader, optimizer, e, std_dev)
#     return test_accuracy  # Return the evaluation metric you want to optimize (e.g., accuracy)

# # Define the bounds for std_dev
# pbounds = {'std_dev': (0.0, 0.2)}  # Adjust the bounds as needed

# # Create the Bayesian Optimization object
# optimizer = BayesianOptimization(
#     f=train_and_evaluate,
#     pbounds=pbounds,
#     verbose=2,  # Adjust verbosity as needed
#     random_state=42,  # Set a random seed for reproducibility
# )

# # Run optimization
# optimizer.maximize(
#     init_points=5,  # Number of random initialization points
#     n_iter=10,  # Number of optimization iterations
# )

# # Retrieve the optimal value for std_dev and the corresponding test accuracy
# optimal_std_dev = optimizer.max['params']['std_dev']
# optimal_test_accuracy = optimizer.max['target']

# print("Optimal std_dev:", optimal_std_dev)
# print("Corresponding test accuracy:", optimal_test_accuracy)

# %% [markdown]
# ### Basic original

# %%
# std_dev = 0.5
# # Run training and testing
# for e in range(epochs):
#     train_loss, train_loss_rec, train_accuracy, epoch_loss, epoch_accuracy, out, out_en = train(net, train_loader, optimizer, e, std_dev)
#     train_avg_loss_rec.append(sum(train_loss_rec) / len(train_loader))

#     test_loss, test_loss_rec, test_accuracy, epoch_loss_test, epoch_accuracy_test, out, out_en = test(net, test_loader, optimizer, e, std_dev)
#     test_avg_loss_rec.append(sum(test_loss_rec) / (len(test_loader)))

#     # # #---------------------------------------------------------- Access the out_en tensor
#     out_en = net.out_en
#     out_en_numpy = out_en.cpu().detach().numpy()
#     # Save with a different name for each epoch
#     out_en_filename = Output_Spikes + f"out_en_epoch_{e + 1}.npy"
#     np.save(out_en_filename, out_en_numpy)



#     # #-----------------------------------------------------------Access the out tensor
#     out = net.out
#     out_numpy = out.cpu().detach().numpy()
#     # Save with a different name for each epoch
#     out_filename = Output_Spikes + f"out_epoch_{e + 1}.npy"
#     np.save(out_filename, out_numpy)
#     # -------------------------------------------------------------------- Intermediate Layers
# # Check if the current epoch is a multiple of 10
#     if (e + 1) % 10 == 0:
#         # Save the epoch_activations dictionary to a file
#         activations_path = Intermediate_Lyrs +  f"activations_epoch_{e + 1}.pkl"
#         with open(activations_path, 'wb') as file:
#             pickle.dump(epoch_activations, file)
#     # Capture activations for the current epoch
#     epoch_activations[e] = {}
#     for i, name in enumerate(hook_names):
#         epoch_activations[e][name] = activation.get(name, None)  # Use get to avoid KeyError






# # # beta_syn=0.0001
