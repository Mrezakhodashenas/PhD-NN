# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrezakhodashenas/PhD-NN/blob/main/clusterNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fbfdedda-0311-46e9-a6ab-490aef3db08d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbfdedda-0311-46e9-a6ab-490aef3db08d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_df = pd.read_csv('train.csv')

color_dict = {'red': 0, 'blue': 1, 'green': 2, 'teal': 3, 'orange': 4, 'purple': 5}
train_df['color'] = train_df.color.apply(lambda x: color_dict[x])

# Shuffling the data ensures model is not overfitting to certain pattern duo sort order.
# it works in_place means we don't need to reset train_df and will be updated behind the scene
np.random.shuffle(train_df.values)
print(train_df.head())
print(train_df.color.unique())
# Out:
#           x         y  color
# 0  0.129270  1.979720      0
# 1 -0.380831  1.693519      0
# 2  0.718693  1.791793      0
# 3  0.722922  0.620655      0
# 4 -0.432689  0.541550      0
# [0 1 2 3 4 5]

# %%
model = keras.Sequential([
	keras.layers.Dense(32, input_shape=(2,), activation='relu'),
	keras.layers.Dense(32, activation='relu'),
	keras.layers.Dense(6, activation='sigmoid')])

model.compile(optimizer='adam',
              loss= keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# model.compile(optimizer='adam', 
# 	          loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
# 	          metrics=['accuracy'])

x = np.column_stack((train_df.x.values, train_df.y.values))

model.fit(x, train_df.color.values, batch_size=4, epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.6109 - accuracy: 0.7728
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1923 - accuracy: 0.9415
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1326 - accuracy: 0.9577
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1065 - accuracy: 0.9652
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0958 - accuracy: 0.9663
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0892 - accuracy: 0.9685
# Epoch 7/10
# ...

# %%
#  Now, evaluating in the Test data:
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84d639d1-52e1-4d0e-be77-e761d3ece346" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84d639d1-52e1-4d0e-be77-e761d3ece346">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
test_df = pd.read_csv('test.csv')
test_x = np.column_stack((test_df.x.values, test_df.y.values))

# for evaluating:
print('Evaluation:')
test_df['color'] = test_df.color.apply(lambda x: color_dict[x])
model.evaluate(test_x, test_df.color.values)
print("Prediction", np.round(model.predict(np.array([[0,3]]))))
# Out:
# Evaluation:
# ...
# 1/1 [==============================] - 0s 101ms/step
# Prediction [[0. 1. 0. 0. 0. 1.]]
